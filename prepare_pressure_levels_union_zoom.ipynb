# %% [markdown]
# # Notebook pour préparer l'union des niveaux pression et la creation des axes/zoom appropriés

# %%
# Select your laboratory among: 'cnrm', 'cerfacs', 'ipsl'
lab='cerfacs'

# %% [markdown]
# ## Lab settings

# %%
if lab=='cnrm' or lab=='cerfacs':
    # This dictionnary should be the same as the one used for creating file_defs.
    # Here , we quoted only those entries useful for creating ping files
    settings={
        #'mips' : {'AerChemMIP','C4MIP','CFMIP','DAMIP', 'FAFMIP' , 'GeoMIP','GMMIP','ISMIP6',\
        #                  'LS3MIP','LUMIP','OMIP','PMIP','RFMIP','ScenarioMIP','CORDEX','SIMIP'},
        # If you want to get comprehensive ping files; use :
        'mips' : {"CMIP6", "AerChemMIP", "C4MIP", "CFMIP", "DAMIP", "DCPP", "FAFMIP", "GeoMIP", "GMMIP", 
                  "HighResMIP", "ISMIP6", "LS3MIP", "LUMIP", "OMIP", "PDRMIP", "PMIP", "RFMIP", "ScenarioMIP", 
                  "SolarMIP", "VolMIP", "CORDEX", "DynVar", "SIMIP", "VIACSAB", "SPECS", "CCMI", "CMIP5", 
                  "CMIP", "DECK"},
        'max_priority' : 3,
        'tierMax'      : 3,
       # Each XIOS  context does adress a number of realms
        'realms_per_context' : { 'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'] ,
                              'arpsfx' : ['atmos', 'atmos atmosChem', 'aerosol', 'atmos land', 'land',
                                         'landIce land',  'aerosol land','land landIce',  'landIce', ],
                              }, 
        "ping_variables_prefix" : "CMIP6_",
        # We account for a file listing the variables which the lab does not want to produce 
        # Format : MIP varname as first column, comment lines begin with '#'
        #"excluded_vars_file":"/cnrm/est/USERS/senesi/public/CMIP6/data_request/cnrm/excluded_vars.txt",
        "excluded_vars_file" : None,
        "excluded_vars" : [],
        # We account for a list of variables which the lab wants to produce in some cases
        "listof_home_vars":None,
        #"listof_home_vars": None,
        "path_extra_tables":None,
        }

# %%
if lab=='cerfacs':  
    #settings["mips"]={'HighResMIP','DCPP'}
    settings["listof_home_vars"]="./inputs/my_listof_home_vars.txt"
    settings["path_extra_tables"]="./inputs/extra_Tables"

# %%
if lab=='ipsl':
    # This dictionnary should be the same as the one used for creating file_defs.
    # Here , we quoted only those entries useful for creating ping files
    settings={
        #'mips' : {'AerChemMIP','C4MIP','CFMIP','DAMIP', 'FAFMIP' , 'GeoMIP','GMMIP','ISMIP6',\
        #                  'LS3MIP','LUMIP','OMIP','PMIP','RFMIP','ScenarioMIP','CORDEX','SIMIP'},
        # If you want to get comprehensive ping files; use :
        'mips' : {"CMIP6", "AerChemMIP", "C4MIP", "CFMIP", "DAMIP", "DCPP", "FAFMIP", "GeoMIP", "GMMIP", 
                  "HighResMIP", "ISMIP6", "LS3MIP", "LUMIP", "OMIP", "PDRMIP", "PMIP", "RFMIP", "ScenarioMIP", 
                  "SolarMIP", "VolMIP", "CORDEX", "DynVar", "SIMIP", "VIACSAB", "SPECS", "CCMI", "CMIP5", 
                  "CMIP", "DECK"},
        'max_priority' : 3,
        'tierMax'      : 3,
       # Each XIOS  context does adress a number of realms
        'realms_per_context' : { 
            'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'],
            'lmdz' : ['atmos', 'atmos land'] , 
            'orchidee': ['land', 'landIce land',  'land landIce', 'landIce'] ,
                              }, 
        "ping_variables_prefix" : "CMIP6_",
        # We account for a file listing the variables which the lab does not want to produce 
        # Format : MIP varname as first column, comment lines begin with '#'
        "excluded_vars_file" : None,
        "excluded_vars" : None,
        # We account for a list of variables which the lab wants to produce in some cases
        "listof_home_vars":None,
        "path_extra_tables":None,
        }

# %%
from dr2xml import gather_AllSimpleVars, isVertDim #, create_axis_def
from vars import simple_Dim
# Out:
# 01.00.04

# %% [markdown]
# ## Select all variables to consider, based on lab settings

# %%
# Attention: appel a select_CMORvars_for_lab sous-jacent sans filtre par experience
svars=gather_AllSimpleVars(settings,printout=False)
# Out:
# DR Error: issue with dimids for  zhalfo in Table  Omon  => no sdims derived.
# DR Error: issue with mipvar for sic  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with dimids for  zhalfo in Table  Omon  => no sdims derived.
# DR Error: issue with mipvar for siltfrac  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with mipvar for sandfrac  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with mipvar for clayfrac  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with mipvar for hfdsnt  => no label_without_area, long_name, stdname, description and units derived.
#
# Number of simplified vars is : 3560
# Info: dimid corresponding to  height50m for variable wind50mmin in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable wind50mmax in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable wsgmax50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  p100 for variable ua100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  p100 for variable hus100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  p100 for variable ta100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  p100 for variable va100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim6hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim6hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  plev12 for variable zg12 in Table MYPROJECT_Myproday  not found in DR => read it in extra coordinates Table:  air_pressure  100000. 85000. 70000. 50000. 25000. 15000. 10000. 7000. 5000. 1000. 500. 200.
# Number of 'cmor' and 'perso' among home variables:  8
# Number of 'extra' among home variables:  178

# %% [markdown]
# # Nouvelles fonctions  (ou évolution d'anciennes) pour union/zoom

# %%
# Fonction create_xios_aux_elmts_defs non utilisee dans ce notebook, juste preparee pour implantation dans dr2xml
# mpmoine_union_modif: renommage de la fonction 'create_xios_field_ref' en 'create_xios_aux_elmts_defs'
def create_xios_aux_elmts_defs(sv,alias,table,lset,sset,end_field_defs,
    field_defs,axis_defs,domain_defs,dummies,context,remap_domain,pingvars) :
    """
    Create a field_ref for a simplified variable object sv (with
    lab prefix for the variable name) and store it in end_field_defs
    under a key=shape
    
    Add field definitions for intermediate variables in dic field_defs
    Add axis  definitions for interpolations in dic axis_defs
    Use pingvars as the list of variables actually defined in ping file

    """
    # By convention, field references are built as prefix_<MIP_variable_name>
    # Such references must be fulfilled using a dedicated filed_def
    # section implementing the match between legacy model field names
    # and such names, called 'ping section'
    #
    # Identify which 'ping' variable ultimatley matches the requested
    # CMOR variable, based on shapes. This may involve building
    # intermediate variables, in order to  apply corresponding operations

    # The preferred order of operation is : vertical interp (which
    # is time-dependant), time-averaging, horizontal operations (using
    # expr=@this)
    
    # nextvar is the field name provided as output of the last
    # operation currently defined
    # mpmoine_union_modif:create_xios_field_ref: on supprime l'usage de netxvar
    #
    #--------------------------------------------------------------------
    # Build XIOS axis elements (stored in axis_defs)
    # Proceed with vertical interpolation if needed
    #---
    # Build XIOS auxilliary field elements (stored in field_defs)
    #--------------------------------------------------------------------
    ssh=sv.spatial_shp
    prefix=lset["ping_variables_prefix"]
    # mpmoine_union_modif:create_xios_field_ref: recup de lwps
    lwps=sv.label_without_psuffix
    # TBD Should handle singletons here
    # TBD Should ensure that various additionnal dims are duly documented by model or pingfile (e.g. tau)
    if ssh[0:4] in ['XY-H','XY-P'] or ssh[0:3] == 'Y-P' :
        # TBD : for now, do not interpolate vertically
        # mpmoine_temporaire:je reactive l'ecriture des axis_def: return
        # mpmoine_last_modif:create_xios_field_ref: on recupere maintenant 'dimids' depuis svar
        # mpmoine_future_modif:create_xios_field_ref: on utilise maintenant sv.sdims pour analyser les dimension
        # mpmoine_question: je ne comprend pas l'usage de nextvar... A priori on ne peut pas avoir plus d'une dimension verticale ?
        for sd in sv.sdims.values():
            if isVertDim(sd):
                # mpmoine_union_modif:create_xios_field_ref: on supprime l'usage de netxvar
                # mpmoine_union_modif:create_xios_field_ref: passage par 2 niveaux de field id auxiliaires rebond (alias et alias2)
                if sd.is_zoom_of:
                    alias+="_"+sd.label
                    alias2=prefix+"_"+lwps+"_union"
                    cible=prefix+"_"+lwps
                    axis_key=sd.zoom_label 
                else:
                    alias+="_"+sd.label
                    alias2=False
                    cible=prefix+"_"+lwps
                    axis_key=sd.label 
                if not cible in pingvars:
                    print "Warning: field id",cible,"expected in pingfile but not found."
                if not alias in pingvars:
                    # Construct an axis for interpolating to this dimension
                    # mpmoine_future_modif:create_xios_field_ref: suppression de l'argument 'field_defs' de create_axis_def qui n'est pas utilise
                    # only zoom or normal axis attached to svar, axis for unions of plevs are managed elsewhere
                    axis_defs[axis_key]=create_axis_def(sd,lwps,lset["ping_variables_prefix"])
                    # Construct a field def for the interpolated variable
                    if alias2:
                        field_defs[alias]='<field id="%-25s field_ref="%-25s axis_ref="%-10s/>'\
                        %(alias+'"',alias2+'"',sd.zoom_label+'"')
                        field_defs[alias2]='<field id="%-25s field_ref="%-25s axis_ref="%-10s/>'\
                        %(alias2+'"',cible+'"',sd.is_zoom_of+'"')
                    else:
                        field_defs[alias]='<field id="%-25s field_ref="%-25s axis_ref="%-10s/>'\
                        %(alias+'"',cible+'"',sd.label+'"')                    
                #TBD what to do for singleton dimension ?
    #
    #--------------------------------------------------------------------
    # Build XIOS domain elements (stored in domain_defs)
    #--------------------------------------------------------------------
     # Analyze 'outermost' time cell_method and translate to 'operation'
    operation,detect_missing = analyze_cell_time_method(sv.cell_methods,sv.label,table)
    # Horizontal operations. Can include horiz re-gridding specification
    # Compute domain name, define it if needed
    domain_ref=None
    if ssh[0:2] == 'Y-' : #zonal mean and atm zonal mean on pressure levels
        # TBD should remap before zona mean
        domain_ref="zonal_mean"
        domain_defs[domain_ref]='<domain id="%s"/>'%domain_ref
    elif ssh[0:2] == 'S-' : #COSP sites; cas S-na, S-A, S-AH
        domain_ref="COSP_sites"
        domain_defs[domain_ref]='<domain id="%s"/>'%domain_ref
    elif ssh[0:2] == 'L-' :
        domain_ref="COSP_curtain"
        domain_defs[domain_ref]='<domain id="%s"/>'%domain_ref
    elif ssh == 'TR-na' or ssh == 'TRS-na' : #transects,   oce or SI
        pass
    elif ssh[0:3] == 'XY-'  : # includes 'XY-AH' : model half-levels
        if remap_domain : domain_ref=remap_domain
    elif ssh[0:3] == 'YB-'  : #basin zonal mean or section
        pass
    elif ssh      == 'na-na'  : # global means or constants
        pass 
    else :
        raise(dr2xml_error("Issue with un-managed spatial shape %s"%ssh))
    #
    #--------------------------------------------------------------------
    # Build XIOS field elements (stored in end_field_defs)
    # including their CMOR attributes
    #--------------------------------------------------------------------
    rep='  <field field_ref="%s" name="%s" ts_enabled="true" '% \
        (alias,sv.label)
    rep+=' operation="%s" detect_missing_value="%s" default_value="1.e+20"'% \
        ( operation,detect_missing)
    rep+=' cell_methods="%s" cell_methods_mode="overwrite"'% sv.cell_methods
    rep+='>\n'
    #
    comment=None
    # Process experiment-specific comment for the variable
    if sv.label in sset['comments'] :
        comment=sset['comments'][sv.label] 
    else: # Process lab-specific comment for the variable
        if sv.label in lset['comments'] : 
            comment=sset['comments'][sv.label] 
    if comment : rep+=wrv('comment',comment) #TBI 
    #
    rep+=wrv("standard_name",sv.stdname)
    #
    desc=sv.description
    if desc : desc=desc.replace(">","").replace("<","")
    rep+=wrv("description",desc)
    #
    rep+=wrv("long_name",sv.long_name)
    if sv.positive != "None" and sv.positive != "" :
        rep+=wrv("positive",sv.positive) 
    rep+=wrv('history','none')
    rep+=wrv('units',sv.stdunits)
    # mpmoine_last_modif: ajout de missing_value pour satisfaire le standard attendu par CMOR
    # mpmoine_last_modif: missing_valueS pour l'instant pour que ça passe le CMORchecker (issue)
    rep+=wrv('missing_values',sv.missing,num_type="double")
    rep+=wrv('cell_measures',sv.cell_measures)
    rep+='     </field>\n'
    #
    shape=domain_ref
    #shape=sv.spatial_shp
    if shape not in end_field_defs : end_field_defs[shape]=[]
    end_field_defs[shape].append(rep)

# %%
# mpmoine_future_modif:create_axis_def: suppression de l'argument 'field_defs' qui n'est pas utilise
def create_axis_def(sdim,prefix):
    """ 
    From a  simplified Dim object, returns an Xios axis definition 
    """
    # mpmoine_future_modif:create_axis_def: plusieurs modifs car on passe maintenant sdim en argument et non dim_name_or_obj
    if sdim is None:
        print "Warning: cannot create an axis_def from "+sdim
        return None

    # mpmoine_union_modif:create_axis_def: nbre de valeurs de l'axe determine aussi si on est en dim singleton
    if sdim.requested:
        # mpmoine_future_modif: je vire le separateur " ", pour regler le pb des " " successifs
        glo_list=sdim.requested.strip(" ").split()
    else:
        glo_list=sdim.value.strip(" ").split()
    glo_list_num=[float(v) for v in glo_list]
    n_glo=len(glo_list)

    # mpmoine_union_modif:create_axis_def: traitement du cas non zoom (classique, comme avant)
    if not sdim.is_zoom_of:
        # Axis is not a zoom of another, write axis_def normally (with value, interpolate_axis,etc.)
        rep='<axis id="%s" '%sdim.label
        if not sdim.positive in [ None, "" ] :
            rep+='positive="%s" '%sdim.positive
        if n_glo>1 :
            # Case of a non-degenerated dimension (not a singleton)
            rep+='n_glo="%g" '%n_glo
            # mpmoine_future_modif: je supprime le -1 pour n_glo car regle avec rstrip/split()
            rep+='value="(0,%g) [%s]"'%(n_glo,sdim.requested)
        else:
            if n_glo!=1:  
                print "Warning: axis is sigleton but has",n_glo,"values"
                return None
            # Singleton case
            rep+='n_glo=%g '%n_glo
            rep+='value=(0,0)[%s]"'%sdim.value
        rep+=' name="%s"'%sdim.out_name
        rep+=' standard_name="%s"'%sdim.stdname
        rep+=' long_name="%s"'%sdim.long_name
        rep+=' unit="%s"'%sdim.units
        rep+='>'
        if sdim.stdname=="air_pressure" : coordname=prefix+"pfull"
        if sdim.stdname=="altitude"     : coordname=prefix+"zg"
        rep+='\n\t<interpolate_axis type="polynomial" order="1"'
        rep+=' coordinate="%s"/>\n</axis>'%coordname
        return rep
    # mpmoine_union_modif:create_axis_def: traitement du cas zoom
    else:
        # Axis is subset of another, write it as a zoom_axis
        rep='<axis id="%s"'%sdim.zoom_label
        rep+=' axis_ref="%s">\n'%sdim.is_zoom_of
        rep+='\t<zoom_axis begin "%g" n="%g"/>\n'%(glo_list_num[-1],n_glo)
        rep+='</axis>'
        return rep

# %%
def create_xios_axis_for_plevs_unions(svars,printout=False): 
    """
    Objective of this function is to optimize Xios vertical interpolation requested in pressure levels. 
    Process in 2 steps:
    * First, search pressure levels unions for each simple variable label without psuffix and build a dictionnary :
        dict_plevs is a 3-levels intelaced dictionnary containing for each var (key=svar-label_without_psuffix), 
        the list of svar (key=svar-label,value=svar-object) per pressure levels set (key=sdim-label):
        { "varX":
              { "plevA": {"svar1":svar1,"svar2":svar2,"svar3":svar3},
                "plevB": {"svar4":svar4,"svar5":svar5},
                "plevC": {"svar6":svar6} },
           "varY":
             { "plevA": {"svar7":svar7},
               "plevD": {"svar8":svar8,"svar9":svar9} }
        }
    * Second, create and write Xios union axis (axis id: union_plevs_<label_without_psuffix>)
    """
    #
    #First, search plev unions for each label_without_psuffix and build dict_plevs
    dict_plevs={}
    for sv in svars:
        if not sv.modeling_realm: print "Warning: no modeling_realm associated to:", \
                                            sv.label, sv.mipTable, sv.mip_era
        for sd in sv.sdims.values():
            if sd.label.startswith("p"): # couvre les dimensions verticales de type 'plev7h' ou 'p850'
                lwps=sv.label_without_psuffix
                if lwps:
                    sv.sdims[sd.label].is_zoom_of="union_plevs_"+lwps
                    if not dict_plevs.has_key(lwps):
                        dict_plevs[lwps]={sd.label:{sv.label:sv}}
                    else:
                        if not dict_plevs[lwps].has_key(sd.label):
                            dict_plevs[lwps].update({sd.label:{sv.label:sv}})
                        else:    
                            if sv.label not in dict_plevs[lwps][sd.label].keys(): 
                                dict_plevs[lwps][sd.label].update({sv.label:sv})
                            else:
                                #-print sv.label,"in table",sv.mipTable,"already listed for",sd.label
                                pass
                    # svar will be expected on a zoom axis of the union. Corresponding vertical dim must
                    # have a zoom_label named plevXX_<lwps>
                    sv.sdims[sd.label].zoom_label='zoom'+'_'+sd.label+"_"+lwps 
                    print "ZOOM_LABEL>", sv.sdims[sd.label].zoom_label
                else:
                    print "Warning: dim is pressure but label_without_psuffix=", lwps, \
                            "for",sv.label, sv.mipTable, sv.mip_era
    #-for k,v in dict_plevs.items(): print k,v
    #
    # Second, create xios axis for union of plevs
    union_axis_defs={}
    for lwps in dict_plevs.keys():
        sdim_union=simple_Dim()
        plevs_union_xios=""
        plevs_union=set()
        for plev in dict_plevs[lwps].keys():  
            plev_values=[]
            for svar in dict_plevs[lwps][plev].values(): 
                if not plev_values:
                    # svar is the first one with this plev => get its level values
                    # mpmoine_note: on reecrase les attributs de sdim_union à chaque nouveau plev. Pas utile mais
                    # mpmoine_note: c'est la facon la plus simple de faire
                    sdsv=svar.sdims[plev]
                    if sdsv.stdname:   sdim_union.stdname=sdsv.stdname
                    if sdsv.long_name: sdim_union.long_name=sdsv.long_name
                    if sdsv.positive:  sdim_union.positive=sdsv.positive
                    if sdsv.out_name:  sdim_union.out_name=sdsv.out_name
                    if sdsv.units:     sdim_union.units=sdsv.units
                    # case of multi pressure levels
                    plev_values=set(sdsv.requested.split())
                    if not plev_values:
                        # case of single pressure level
                        plev_values=set(sdsv.value.split())
                    plevs_union=plevs_union.union(plev_values)
                    if printout: print "    -- on",plev,":",plev_values 
                if printout: print "       *",svar.label,"(",svar.mipTable,")"
        list_plevs_union=list(plevs_union)
        list_plevs_union.sort(reverse=True)
        for lev in list_plevs_union: plevs_union_xios+=" "+lev
        if printout: print ">>> XIOS plevs union:", plevs_union_xios
        sdim_union.label="union_levs_"+lwps
        sdim_union.requested=plevs_union_xios
        axis_def=create_axis_def(sdim_union,settings["ping_variables_prefix"])
        union_axis_defs.update({sdim_union.label:axis_def})
    return union_axis_defs

# %% [markdown]
# # Construction des axes d'union de Plevs

# %%
union_axis_defs=create_xios_axis_for_plevs_unions(svars)
# Out:
# Warning: no modeling_realm associated to: vegFrac Eyr CMIP6
# ZOOM_LABEL> zoom_plev39_zg
# ZOOM_LABEL> zoom_plev39_tntrl
# ZOOM_LABEL> zoom_plev39_tntrscs
# ZOOM_LABEL> zoom_plev39_tntmp
# ZOOM_LABEL> zoom_plev39_tntc
# ZOOM_LABEL> zoom_plev39_tntrs
# ZOOM_LABEL> zoom_plev39_tntscp
# ZOOM_LABEL> zoom_plev39_tntrlcs
# ZOOM_LABEL> zoom_plev39_tntogw
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_wap
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev7c_clisccp
# ZOOM_LABEL> zoom_plev7h_va
# ZOOM_LABEL> zoom_plev7h_hus
# ZOOM_LABEL> zoom_plev7h_wap
# ZOOM_LABEL> zoom_plev7h_ua
# ZOOM_LABEL> zoom_plev7h_ta
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev19_n2o
# ZOOM_LABEL> zoom_plev19_n2oClim
# ZOOM_LABEL> zoom_plev19_ch4
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev19_co2Clim
# ZOOM_LABEL> zoom_plev19_wap
# ZOOM_LABEL> zoom_plev19_hur
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_o3Clim
# ZOOM_LABEL> zoom_plev19_o3
# ZOOM_LABEL> zoom_plev19_co2
# ZOOM_LABEL> zoom_plev19_ch4Clim
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev8_zg
# ZOOM_LABEL> zoom_plev8_ua
# ZOOM_LABEL> zoom_plev8_ta
# ZOOM_LABEL> zoom_plev8_wap
# ZOOM_LABEL> zoom_plev8_hus
# ZOOM_LABEL> zoom_plev8_hur
# ZOOM_LABEL> zoom_plev8_va
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev19_wap
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev8_zg
# ZOOM_LABEL> zoom_plev8_ua
# ZOOM_LABEL> zoom_plev8_ta
# ZOOM_LABEL> zoom_plev8_wap
# ZOOM_LABEL> zoom_plev8_hus
# ZOOM_LABEL> zoom_plev8_hur
# ZOOM_LABEL> zoom_plev8_va
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev19_wap
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev39_epfy
# ZOOM_LABEL> zoom_plev39_utendepfd
# ZOOM_LABEL> zoom_plev39_zmtnt
# ZOOM_LABEL> zoom_plev39_vtem
# ZOOM_LABEL> zoom_plev39_wtem
# ZOOM_LABEL> zoom_plev39_epfz
# ZOOM_LABEL> zoom_plev7c_clisccp
# ZOOM_LABEL> zoom_plev39_ta
# ZOOM_LABEL> zoom_plev27_ta
# ZOOM_LABEL> zoom_plev27_hus
# ZOOM_LABEL> zoom_plev27_rainmxrat
# ZOOM_LABEL> zoom_plev27_va
# ZOOM_LABEL> zoom_plev27_snowmxrat
# ZOOM_LABEL> zoom_plev27_ua
# ZOOM_LABEL> zoom_plev27_tntmp
# ZOOM_LABEL> zoom_plev27_cldicemxrat
# ZOOM_LABEL> zoom_plev27_zg
# ZOOM_LABEL> zoom_plev27_tntrl
# ZOOM_LABEL> zoom_plev27_grplmxrat
# ZOOM_LABEL> zoom_plev27_tntrs
# ZOOM_LABEL> zoom_plev27_cldwatmxrat
# ZOOM_LABEL> zoom_plev27_cldwatmxrat
# ZOOM_LABEL> zoom_plev27_zg
# ZOOM_LABEL> zoom_plev27_hus
# ZOOM_LABEL> zoom_plev27_grplmxrat
# ZOOM_LABEL> zoom_plev27_snowmxrat
# ZOOM_LABEL> zoom_plev27_pfull
# ZOOM_LABEL> zoom_plev27_ta
# ZOOM_LABEL> zoom_plev27_rainmxrat
# ZOOM_LABEL> zoom_plev27_cldicemxrat
# ZOOM_LABEL> zoom_plev7c_clisccp
# Warning: no modeling_realm associated to: zg 6hrPlev CMIP6
# Warning: no modeling_realm associated to: ta 6hrPlev CMIP6
# Warning: no modeling_realm associated to: hus 6hrPlev CMIP6
# Warning: no modeling_realm associated to: ua 6hrPlev CMIP6
# Warning: no modeling_realm associated to: va 6hrPlev CMIP6
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev19_n2o
# ZOOM_LABEL> zoom_plev19_n2oClim
# ZOOM_LABEL> zoom_plev19_ch4
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev19_co2Clim
# ZOOM_LABEL> zoom_plev19_wap
# ZOOM_LABEL> zoom_plev19_hur
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_o3Clim
# ZOOM_LABEL> zoom_plev19_o3
# ZOOM_LABEL> zoom_plev19_co2
# ZOOM_LABEL> zoom_plev19_ch4Clim
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev3_va
# ZOOM_LABEL> zoom_plev3_wap
# ZOOM_LABEL> zoom_plev3_ta
# ZOOM_LABEL> zoom_plev3_ua
# ZOOM_LABEL> zoom_p850_ua
# ZOOM_LABEL> zoom_p200_va
# ZOOM_LABEL> zoom_p850_va
# ZOOM_LABEL> zoom_p200_ua
# ZOOM_LABEL> zoom_plev8_zg
# ZOOM_LABEL> zoom_plev8_ua
# ZOOM_LABEL> zoom_plev8_ta
# ZOOM_LABEL> zoom_plev8_wap
# ZOOM_LABEL> zoom_plev8_hus
# ZOOM_LABEL> zoom_plev8_hur
# ZOOM_LABEL> zoom_plev8_va
# ZOOM_LABEL> zoom_plev7c_jpdftaureicemodis
# ZOOM_LABEL> zoom_plev7c_jpdftaureliqmodis
# ZOOM_LABEL> zoom_p220_clhcalipso
# ZOOM_LABEL> zoom_p560_clmcalipso
# ZOOM_LABEL> zoom_p840_cllcalipso
# ZOOM_LABEL> zoom_p850_rv
# ZOOM_LABEL> zoom_p1000_zg
# ZOOM_LABEL> zoom_p850_ta
# ZOOM_LABEL> zoom_plev7c_jpdftaureliqmodis
# ZOOM_LABEL> zoom_plev7c_jpdftaureicemodis
# ZOOM_LABEL> zoom_p560_clmcalipso
# ZOOM_LABEL> zoom_p840_cllcalipso
# ZOOM_LABEL> zoom_p220_clhcalipso
# ZOOM_LABEL> zoom_plev39_va
# ZOOM_LABEL> zoom_plev39_ta
# ZOOM_LABEL> zoom_plev39_ua
# ZOOM_LABEL> zoom_plev39_hus
# ZOOM_LABEL> zoom_plev39_zg
# ZOOM_LABEL> zoom_plev39_utendnogw
# ZOOM_LABEL> zoom_plev39_utendwtem
# ZOOM_LABEL> zoom_plev39_utendvtem
# ZOOM_LABEL> zoom_plev39_utendogw
# ZOOM_LABEL> zoom_plev39_ua
# ZOOM_LABEL> zoom_plev39_psitem
# ZOOM_LABEL> zoom_plev3_ta
# ZOOM_LABEL> zoom_plev3_ua
# ZOOM_LABEL> zoom_plev3_va
# ZOOM_LABEL> zoom_plev39_epfy
# ZOOM_LABEL> zoom_plev39_utendepfd
# ZOOM_LABEL> zoom_plev39_tntnogw
# ZOOM_LABEL> zoom_plev39_vtem
# ZOOM_LABEL> zoom_plev39_wtem
# ZOOM_LABEL> zoom_plev39_epfz
# ZOOM_LABEL> zoom_plev39_meanage
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_wap
# Warning: no modeling_realm associated to: areacella Efx CMIP6
# ZOOM_LABEL> zoom_plev19_tntsw
# ZOOM_LABEL> zoom_plev19_utendogw
# ZOOM_LABEL> zoom_plev19_diabdrag
# ZOOM_LABEL> zoom_plev19_utendnogw
# ZOOM_LABEL> zoom_plev7h_ta
# ZOOM_LABEL> zoom_plev7h_zg
# ZOOM_LABEL> zoom_plev7h_hus
# ZOOM_LABEL> zoom_plev3_vortmean
# ZOOM_LABEL> zoom_plev7h_ua
# ZOOM_LABEL> zoom_plev7h_va
# ZOOM_LABEL> zoom_plev39_utendnogw
# ZOOM_LABEL> zoom_plev39_vtendnogw
# ZOOM_LABEL> zoom_plev39_ygwdparam
# ZOOM_LABEL> zoom_plev39_xgwdparam
# ZOOM_LABEL> zoom_plev39_oh
# ZOOM_LABEL> zoom_plev39_zg
# ZOOM_LABEL> zoom_plev39_o3
# ZOOM_LABEL> zoom_plev39_bry
# ZOOM_LABEL> zoom_plev39_noy
# ZOOM_LABEL> zoom_plev39_cly
# ZOOM_LABEL> zoom_plev39_n2o
# ZOOM_LABEL> zoom_plev39_hcl
# ZOOM_LABEL> zoom_plev39_meanage
# ZOOM_LABEL> zoom_plev39_va
# ZOOM_LABEL> zoom_plev39_ch4
# ZOOM_LABEL> zoom_plev39_hno3
# ZOOM_LABEL> zoom_plev39_ua
# ZOOM_LABEL> zoom_plev39_ho2
# ZOOM_LABEL> zoom_plev39_h2o
# Warning: no modeling_realm associated to: vas E3hr CMIP6
# Warning: no modeling_realm associated to: uas E3hr CMIP6
# ZOOM_LABEL> zoom_plev39_wtem
# ZOOM_LABEL> zoom_plev39_utendepfd
# ZOOM_LABEL> zoom_plev39_vtem
# ZOOM_LABEL> zoom_plev39_epfz
# ZOOM_LABEL> zoom_plev39_epfy
# ZOOM_LABEL> zoom_plev19_utendogw
# ZOOM_LABEL> zoom_plev19_vtendogw
# ZOOM_LABEL> zoom_plev19_utendnogw
# ZOOM_LABEL> zoom_plev19_vtendnogw
# ZOOM_LABEL> zoom_plev39_ta
# ZOOM_LABEL> zoom_plev7c_clisccp
# ZOOM_LABEL> zoom_p840_cllcalipso
# ZOOM_LABEL> zoom_plev7c_clisccp
# ZOOM_LABEL> zoom_p220_clhcalipso
# ZOOM_LABEL> zoom_p560_clmcalipso
# ZOOM_LABEL> zoom_p500_ta
# ZOOM_LABEL> zoom_p850_ua
# ZOOM_LABEL> zoom_p850_ta
# ZOOM_LABEL> zoom_p850_va
# ZOOM_LABEL> zoom_p200_ua
# ZOOM_LABEL> zoom_p850_hus
# ZOOM_LABEL> zoom_p200_va
# ZOOM_LABEL> zoom_p850_rv
# ZOOM_LABEL> zoom_plev7c_jpdftaureliqmodis
# ZOOM_LABEL> zoom_plev7c_jpdftaureicemodis
# ZOOM_LABEL> zoom_plev39_oxprod
# ZOOM_LABEL> zoom_plev39_vmrox
# ZOOM_LABEL> zoom_plev39_jo3
# ZOOM_LABEL> zoom_plev39_oxloss
# ZOOM_LABEL> zoom_plev39_jo2
# ZOOM_LABEL> zoom_plev19_vtendogw
# ZOOM_LABEL> zoom_plev19_vtendnogw
# ZOOM_LABEL> zoom_plev19_n2o
# ZOOM_LABEL> zoom_plev19_n2oClim
# ZOOM_LABEL> zoom_plev19_ch4
# ZOOM_LABEL> zoom_plev19_co2Clim
# ZOOM_LABEL> zoom_plev19_hur
# ZOOM_LABEL> zoom_plev19_o3Clim
# ZOOM_LABEL> zoom_plev19_o3
# ZOOM_LABEL> zoom_plev19_co2
# ZOOM_LABEL> zoom_plev19_ch4Clim
# ZOOM_LABEL> zoom_p500_wap
# ZOOM_LABEL> zoom_p700_ta
# ZOOM_LABEL> zoom_plev39_tntnogw
# ZOOM_LABEL> zoom_plev3_ua
# ZOOM_LABEL> zoom_plev3_ta
# ZOOM_LABEL> zoom_plev3_va
# ZOOM_LABEL> zoom_plev3_ua
# ZOOM_LABEL> zoom_plev4_wap
# ZOOM_LABEL> zoom_plev7h_wbptemp
# ZOOM_LABEL> zoom_plev3_va
# ZOOM_LABEL> zoom_plev4_hus
# ZOOM_LABEL> zoom_plev3_ua
# ZOOM_LABEL> zoom_plev3_ta
# ZOOM_LABEL> zoom_plev3_va
# ZOOM_LABEL> zoom_plev3_ta
# ZOOM_LABEL> zoom_p500_wap
# ZOOM_LABEL> zoom_p700_ta
# ZOOM_LABEL> zoom_plev39_tntrl
# ZOOM_LABEL> zoom_plev39_tntrscs
# ZOOM_LABEL> zoom_plev39_tntmp
# ZOOM_LABEL> zoom_plev39_tntc
# ZOOM_LABEL> zoom_plev39_tntrs
# ZOOM_LABEL> zoom_plev39_tntscp
# ZOOM_LABEL> zoom_plev39_tntrlcs
# ZOOM_LABEL> zoom_plev39_tntogw
# ZOOM_LABEL> zoom_plev27_wap
# ZOOM_LABEL> zoom_plev27_vtendnogw
# ZOOM_LABEL> zoom_plev27_ta
# ZOOM_LABEL> zoom_plev27_ua
# ZOOM_LABEL> zoom_plev27_utendnogw
# ZOOM_LABEL> zoom_plev27_va
# ZOOM_LABEL> zoom_plev27_zg
# ZOOM_LABEL> zoom_plev27_tntr
# ZOOM_LABEL> zoom_plev7h_vortmean
# ZOOM_LABEL> zoom_p100_ua100
# ZOOM_LABEL> zoom_plev7h_zg
# ZOOM_LABEL> zoom_p1000_hus
# ZOOM_LABEL> zoom_p100_hus100
# ZOOM_LABEL> zoom_p100_ta100
# ZOOM_LABEL> zoom_p100_va100
# ZOOM_LABEL> zoom_p1000_va
# ZOOM_LABEL> zoom_p1000_ua
# ZOOM_LABEL> zoom_plev4_hus
# ZOOM_LABEL> zoom_plev4_ua
# ZOOM_LABEL> zoom_plev4_va
# ZOOM_LABEL> zoom_p1000_hus
# ZOOM_LABEL> zoom_p1000_va
# ZOOM_LABEL> zoom_p1000_ua
# ZOOM_LABEL> zoom_plev19_zg
# ZOOM_LABEL> zoom_plev23_va2
# ZOOM_LABEL> zoom_plev10_zg
# ZOOM_LABEL> zoom_plev10_ua
# ZOOM_LABEL> zoom_plev19_hus
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev23_wap2
# ZOOM_LABEL> zoom_plev10_va
# ZOOM_LABEL> zoom_plev19_wap
# ZOOM_LABEL> zoom_plev23_ta2
# ZOOM_LABEL> zoom_plev23_ua2
# ZOOM_LABEL> zoom_plev23_zg2
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev23_hus2
# ZOOM_LABEL> zoom_plev10_ta
# ZOOM_LABEL> zoom_plev10_hus
# ZOOM_LABEL> zoom_plev19_ta
# ZOOM_LABEL> zoom_plev10_wap
# ZOOM_LABEL> zoom_plev19_va
# ZOOM_LABEL> zoom_plev19_ua
# ZOOM_LABEL> zoom_plev39_va
# ZOOM_LABEL> zoom_plev39_epfluxdiv
# ZOOM_LABEL> zoom_plev39_zg
# ZOOM_LABEL> zoom_plev39_vstarbar
# ZOOM_LABEL> zoom_plev39_wstarbar
# ZOOM_LABEL> zoom_plev39_xnonoroggwdparam
# ZOOM_LABEL> zoom_plev39_ua
# ZOOM_LABEL> zoom_plev39_ynonoroggwdparam
# ZOOM_LABEL> zoom_plev12_zg

# %%
for axd in union_axis_defs.values(): print axd
# Out:
# <axis id="union_levs_tntrlcs" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_n2oClim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntrscs" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntrs" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_utendvtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntrl" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_vmrox" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ua" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_epfz" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_xgwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_hno3" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_va2" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_jo2" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_jo3" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_pfull" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_vstarbar" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_co2Clim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_noy" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_o3Clim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ta2" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_utendepfd" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ua2" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntnogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntsw" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_va" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_h2o" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_jpdftaureicemodis" positive="down" n_glo="7" value="(0,7) [ 90000. 9000. 74000. 62000. 50000. 37500. 24500.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ygwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ta100" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_utendwtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_hcl" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_hus100" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_oxloss" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_hus2" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_va100" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ho2" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_zg" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_n2o" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_epfy" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntscp" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntr" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_cly" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_wstarbar" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_o3" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_co2" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntc" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_bry" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ynonoroggwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_vtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_utendogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_cllcalipso" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_clhcalipso" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_zmtnt" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ch4" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ua100" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_vtendnogw" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_utendnogw" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_jpdftaureliqmodis" positive="down" n_glo="7" value="(0,7) [ 90000. 9000. 74000. 62000. 50000. 37500. 24500.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_cldicemxrat" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_rv" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_hur" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_hus" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_oxprod" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_zg2" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_wbptemp" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_rainmxrat" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_cldwatmxrat" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_wtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_tntmp" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_vtendogw" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_epfluxdiv" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_oh" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_grplmxrat" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ta" positive="down" n_glo="54" value="(0,54) [ 97500. 95000. 92500. 90000. 9000. 87500. 85000. 82500. 80000. 8000. 77500. 75000. 70000. 7000. 700. 70. 7. 65000. 60000. 55000. 50000. 5000. 500. 50. 5. 45000. 40000. 40. 35000. 30000. 3000. 300. 30. 3. 25000. 22500. 20000. 2000. 200. 20. 17500. 17000. 15000. 1500. 150. 15. 13000. 12500. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_psitem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_wap2" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_vortmean" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_snowmxrat" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_clisccp" positive="down" n_glo="7" value="(0,7) [ 90000. 9000. 74000. 62000. 50000. 37500. 24500.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_xnonoroggwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_diabdrag" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_wap" positive="down" n_glo="34" value="(0,34) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 7000. 65000. 60000. 55000. 50000. 5000. 500. 45000. 40000. 35000. 30000. 3000. 25000. 22500. 20000. 2000. 17500. 15000. 12500. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_ch4Clim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_clmcalipso" positive="down" n_glo=1 value=(0,0)[False]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>
# <axis id="union_levs_meanage" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 	<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# </axis>

# %% [markdown]
# # Construction des axes de zoom

# %%
axis_defs={}
for sv in svars:
    lwps=sv.label_without_psuffix
    for sd in sv.sdims.values():
        if isVertDim(sd):
            if sd.is_zoom_of: k=sd.zoom_label 
            else: k=sd.label
            axis_defs[k]=create_axis_def(sd,settings["ping_variables_prefix"])
#for k,v in axis_defs.items(): print k,'\n',v

# %% [markdown]
# # Juste quelques tests de devel...

# %%
# Test
for sv in svars:
    for sd in sv.sdims.values():
        if sd.label.startswith("p"):
            #print "--- ",sv.label
            #print "    * ",sd.label,"axis is zoom of",sd.is_zoom_of
            pass

# %%
# Test
values=[85000.,50000.,0.]
s="850"
print any (s in str(v) for v in values)
# Out:
# True

# %%
# Test
plev_suffixes=["1000","200","220","500","560","700","840","850","10","19","23","27","39","3","3h","4","7c","7h","8"]
for s in plev_suffixes:
    for svar in svars:
        if any((svar.sdims[k].label.startswith("p") and svar.sdims[k].label.endswith(s)) for k in svar.sdims.iterkeys()): 
            label_out=svar.label
            if svar.label.endswith(s):
                label_out=svar.label.replace(s,"")
            print svar.label,"--->",label_out
# Out:
# zg1000 ---> zg
# hus1000 ---> hus
# va1000 ---> va
# ua1000 ---> ua
# hus1000 ---> hus
# va1000 ---> va
# ua1000 ---> ua
# va200 ---> va
# ua200 ---> ua
# ua200 ---> ua
# va200 ---> va
# clhcalipso ---> clhcalipso
# clhcalipso ---> clhcalipso
# clhcalipso ---> clhcalipso
# ta500 ---> ta
# wap500 ---> wap
# wap500 ---> wap
# clmcalipso ---> clmcalipso
# clmcalipso ---> clmcalipso
# clmcalipso ---> clmcalipso
# ta700 ---> ta
# ta700 ---> ta
# cllcalipso ---> cllcalipso
# cllcalipso ---> cllcalipso
# cllcalipso ---> cllcalipso
# ua850 ---> ua
# va850 ---> va
# rv850 ---> rv
# ta850 ---> ta
# ua850 ---> ua
# ta850 ---> ta
# va850 ---> va
# hus850 ---> hus
# rv850 ---> rv
# zg10 ---> zg
# ua10 ---> ua
# va10 ---> va
# ta10 ---> ta
# hus10 ---> hus
# wap10 ---> wap
# ta ---> ta
# hus ---> hus
# zg ---> zg
# va ---> va
# wap ---> wap
# ua ---> ua
# ta ---> ta
# n2o ---> n2o
# n2oClim ---> n2oClim
# ch4 ---> ch4
# hus ---> hus
# zg ---> zg
# co2Clim ---> co2Clim
# wap ---> wap
# hur ---> hur
# va ---> va
# o3Clim ---> o3Clim
# o3 ---> o3
# co2 ---> co2
# ch4Clim ---> ch4Clim
# ua ---> ua
# va ---> va
# zg ---> zg
# ta ---> ta
# wap ---> wap
# hus ---> hus
# ua ---> ua
# va ---> va
# zg ---> zg
# ta ---> ta
# wap ---> wap
# hus ---> hus
# ua ---> ua
# ta ---> ta
# n2o ---> n2o
# n2oClim ---> n2oClim
# ch4 ---> ch4
# hus ---> hus
# zg ---> zg
# co2Clim ---> co2Clim
# wap ---> wap
# hur ---> hur
# va ---> va
# o3Clim ---> o3Clim
# o3 ---> o3
# co2 ---> co2
# ch4Clim ---> ch4Clim
# ua ---> ua
# zg ---> zg
# ta ---> ta
# ua ---> ua
# va ---> va
# hus ---> hus
# wap ---> wap
# tntsw ---> tntsw
# utendogw ---> utendogw
# diabdrag ---> diabdrag
# utendnogw ---> utendnogw
# utendogw ---> utendogw
# vtendogw ---> vtendogw
# utendnogw ---> utendnogw
# vtendnogw ---> vtendnogw
# vtendogw ---> vtendogw
# vtendnogw ---> vtendnogw
# n2o ---> n2o
# n2oClim ---> n2oClim
# ch4 ---> ch4
# co2Clim ---> co2Clim
# hur ---> hur
# o3Clim ---> o3Clim
# o3 ---> o3
# co2 ---> co2
# ch4Clim ---> ch4Clim
# zg19 ---> zg
# hus19 ---> hus
# ua19 ---> ua
# wap19 ---> wap
# va19 ---> va
# ta19 ---> ta
# va ---> va
# ua ---> ua
# va23 ---> va
# wap23 ---> wap
# ta23 ---> ta
# ua23 ---> ua
# zg23 ---> zg
# hus23 ---> hus
# ta27 ---> ta
# hus27 ---> hus
# rainmxrat27 ---> rainmxrat
# va27 ---> va
# snowmxrat27 ---> snowmxrat
# ua27 ---> ua
# tntmp27 ---> tntmp
# cldicemxrat27 ---> cldicemxrat
# zg27 ---> zg
# tntrl27 ---> tntrl
# grplmxrat27 ---> grplmxrat
# tntrs27 ---> tntrs
# cldwatmxrat27 ---> cldwatmxrat
# cldwatmxrat27 ---> cldwatmxrat
# zg27 ---> zg
# hus27 ---> hus
# grplmxrat27 ---> grplmxrat
# snowmxrat27 ---> snowmxrat
# pfull27 ---> pfull
# ta27 ---> ta
# rainmxrat27 ---> rainmxrat
# cldicemxrat27 ---> cldicemxrat
# wap27 ---> wap
# vtendnogw27 ---> vtendnogw
# ta27 ---> ta
# ua27 ---> ua
# utendnogw27 ---> utendnogw
# va27 ---> va
# zg27 ---> zg
# tntr27 ---> tntr
# zg ---> zg
# tntrl ---> tntrl
# tntrscs ---> tntrscs
# tntmp ---> tntmp
# tntc ---> tntc
# tntrs ---> tntrs
# tntscp ---> tntscp
# tntrlcs ---> tntrlcs
# tntogw ---> tntogw
# epfy ---> epfy
# utendepfd ---> utendepfd
# zmtnt ---> zmtnt
# vtem ---> vtem
# wtem ---> wtem
# epfz ---> epfz
# ta ---> ta
# va ---> va
# ta ---> ta
# ua ---> ua
# hus ---> hus
# zg ---> zg
# utendnogw ---> utendnogw
# utendwtem ---> utendwtem
# utendvtem ---> utendvtem
# utendogw ---> utendogw
# ua ---> ua
# psitem ---> psitem
# epfy ---> epfy
# utendepfd ---> utendepfd
# tntnogw ---> tntnogw
# vtem ---> vtem
# wtem ---> wtem
# epfz ---> epfz
# meanage ---> meanage
# utendnogw ---> utendnogw
# vtendnogw ---> vtendnogw
# ygwdparam ---> ygwdparam
# xgwdparam ---> xgwdparam
# oh ---> oh
# zg ---> zg
# o3 ---> o3
# bry ---> bry
# noy ---> noy
# cly ---> cly
# n2o ---> n2o
# hcl ---> hcl
# meanage ---> meanage
# va ---> va
# ch4 ---> ch4
# hno3 ---> hno3
# ua ---> ua
# ho2 ---> ho2
# h2o ---> h2o
# wtem ---> wtem
# utendepfd ---> utendepfd
# vtem ---> vtem
# epfz ---> epfz
# epfy ---> epfy
# ta ---> ta
# oxprod ---> oxprod
# vmrox ---> vmrox
# jo3 ---> jo3
# oxloss ---> oxloss
# jo2 ---> jo2
# tntnogw ---> tntnogw
# tntrl ---> tntrl
# tntrscs ---> tntrscs
# tntmp ---> tntmp
# tntc ---> tntc
# tntrs ---> tntrs
# tntscp ---> tntscp
# tntrlcs ---> tntrlcs
# tntogw ---> tntogw
# va ---> va
# epfluxdiv ---> epfluxdiv
# zg ---> zg
# vstarbar ---> vstarbar
# wstarbar ---> wstarbar
# xnonoroggwdparam ---> xnonoroggwdparam
# ua ---> ua
# ynonoroggwdparam ---> ynonoroggwdparam
# va ---> va
# wap ---> wap
# ta ---> ta
# ua ---> ua
# ta ---> ta
# ua ---> ua
# va ---> va
# vortmean ---> vortmean
# ua ---> ua
# ta ---> ta
# va ---> va
# ua ---> ua
# va ---> va
# ua ---> ua
# ta ---> ta
# va ---> va
# ta ---> ta
# va23 ---> va2
# wap23 ---> wap2
# ta23 ---> ta2
# ua23 ---> ua2
# zg23 ---> zg2
# hus23 ---> hus2
# wap4 ---> wap
# hus4 ---> hus
# hus4 ---> hus
# ua4 ---> ua
# va4 ---> va
# clisccp ---> clisccp
# clisccp ---> clisccp
# clisccp ---> clisccp
# jpdftaureicemodis ---> jpdftaureicemodis
# jpdftaureliqmodis ---> jpdftaureliqmodis
# jpdftaureliqmodis ---> jpdftaureliqmodis
# jpdftaureicemodis ---> jpdftaureicemodis
# clisccp ---> clisccp
# clisccp ---> clisccp
# jpdftaureliqmodis ---> jpdftaureliqmodis
# jpdftaureicemodis ---> jpdftaureicemodis
# va7h ---> va
# hus7h ---> hus
# wap7h ---> wap
# ua7h ---> ua
# ta7h ---> ta
# ta7h ---> ta
# zg7h ---> zg
# hus7h ---> hus
# ua7h ---> ua
# va7h ---> va
# wbptemp7h ---> wbptemp
# vortmean ---> vortmean
# zg7h ---> zg
# zg ---> zg
# ua ---> ua
# ta ---> ta
# wap ---> wap
# hus ---> hus
# hur ---> hur
# va ---> va
# zg ---> zg
# ua ---> ua
# ta ---> ta
# wap ---> wap
# hus ---> hus
# hur ---> hur
# va ---> va
# zg ---> zg
# ua ---> ua
# ta ---> ta
# wap ---> wap
# hus ---> hus
# hur ---> hur
# va ---> va
