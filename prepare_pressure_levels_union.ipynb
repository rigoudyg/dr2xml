# %% [markdown]
# # Notebook pour préparer l'union des niveaux pression et la creation des axes/zoom appropriés

# %%
# Select your laboratory among: 'cnrm', 'cerfacs', 'ipsl'
lab='cerfacs'

# %% [markdown]
# ## Lab settings

# %%
if lab=='cnrm' or lab=='cerfacs':
    # This dictionnary should be the same as the one used for creating file_defs.
    # Here , we quoted only those entries useful for creating ping files
    settings={
        #'mips' : {'AerChemMIP','C4MIP','CFMIP','DAMIP', 'FAFMIP' , 'GeoMIP','GMMIP','ISMIP6',\
        #                  'LS3MIP','LUMIP','OMIP','PMIP','RFMIP','ScenarioMIP','CORDEX','SIMIP'},
        # If you want to get comprehensive ping files; use :
        'mips' : {"CMIP6", "AerChemMIP", "C4MIP", "CFMIP", "DAMIP", "DCPP", "FAFMIP", "GeoMIP", "GMMIP", 
                  "HighResMIP", "ISMIP6", "LS3MIP", "LUMIP", "OMIP", "PDRMIP", "PMIP", "RFMIP", "ScenarioMIP", 
                  "SolarMIP", "VolMIP", "CORDEX", "DynVar", "SIMIP", "VIACSAB", "SPECS", "CCMI", "CMIP5", 
                  "CMIP", "DECK"},
        'max_priority' : 3,
        'tierMax'      : 3,
       # Each XIOS  context does adress a number of realms
        'realms_per_context' : { 'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'] ,
                              'arpsfx' : ['atmos', 'atmos atmosChem', 'aerosol', 'atmos land', 'land',
                                         'landIce land',  'aerosol land','land landIce',  'landIce', ],
                              }, 
        "ping_variables_prefix" : "CMIP6_",
        # We account for a file listing the variables which the lab does not want to produce 
        # Format : MIP varname as first column, comment lines begin with '#'
        #"excluded_vars_file":"/cnrm/est/USERS/senesi/public/CMIP6/data_request/cnrm/excluded_vars.txt",
        "excluded_vars_file" : None,
        "excluded_vars" : [],
        # We account for a list of variables which the lab wants to produce in some cases
        "listof_home_vars":None,
        #"listof_home_vars": None,
        "path_extra_tables":None,
        }

# %%
if lab=='cerfacs':  
    #settings["mips"]={'HighResMIP','DCPP'}
    settings["listof_home_vars"]="./inputs/my_listof_home_vars.txt"
    settings["path_extra_tables"]="./inputs/extra_Tables"

# %%
if lab=='ipsl':
    # This dictionnary should be the same as the one used for creating file_defs.
    # Here , we quoted only those entries useful for creating ping files
    settings={
        #'mips' : {'AerChemMIP','C4MIP','CFMIP','DAMIP', 'FAFMIP' , 'GeoMIP','GMMIP','ISMIP6',\
        #                  'LS3MIP','LUMIP','OMIP','PMIP','RFMIP','ScenarioMIP','CORDEX','SIMIP'},
        # If you want to get comprehensive ping files; use :
        'mips' : {"CMIP6", "AerChemMIP", "C4MIP", "CFMIP", "DAMIP", "DCPP", "FAFMIP", "GeoMIP", "GMMIP", 
                  "HighResMIP", "ISMIP6", "LS3MIP", "LUMIP", "OMIP", "PDRMIP", "PMIP", "RFMIP", "ScenarioMIP", 
                  "SolarMIP", "VolMIP", "CORDEX", "DynVar", "SIMIP", "VIACSAB", "SPECS", "CCMI", "CMIP5", 
                  "CMIP", "DECK"},
        'max_priority' : 3,
        'tierMax'      : 3,
       # Each XIOS  context does adress a number of realms
        'realms_per_context' : { 
            'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'],
            'lmdz' : ['atmos', 'atmos land'] , 
            'orchidee': ['land', 'landIce land',  'land landIce', 'landIce'] ,
                              }, 
        "ping_variables_prefix" : "CMIP6_",
        # We account for a file listing the variables which the lab does not want to produce 
        # Format : MIP varname as first column, comment lines begin with '#'
        "excluded_vars_file" : None,
        "excluded_vars" : None,
        # We account for a list of variables which the lab wants to produce in some cases
        "listof_home_vars":None,
        "path_extra_tables":None,
        }

# %%
from dr2xml import gather_AllSimpleVars, create_axis_def
from vars import simple_Dim
# Out:
# 01.00.04

# %% [markdown]
# ## Select all variables to consider, based on lab settings

# %%
# Attention: appel a select_CMORvars_for_lab sous-jacent sans filtre par experience
svars=gather_AllSimpleVars(settings,printout=False)
# Out:
# DR Error: issue with mipvar for sic  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with dimids for  zhalfo in Table  Omon  => no sdims derived.
# DR Error: issue with dimids for  zhalfo in Table  Omon  => no sdims derived.
# DR Error: issue with mipvar for hfdsnt  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with mipvar for siltfrac  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with mipvar for sandfrac  => no label_without_area, long_name, stdname, description and units derived.
# DR Error: issue with mipvar for clayfrac  => no label_without_area, long_name, stdname, description and units derived.
#
# Number of simplified vars is : 3560
# Info: dimid corresponding to  height50m for variable wind50mmin in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable wind50mmax in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable wsgmax50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  p100 for variable ua100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  p100 for variable hus100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  p100 for variable ta100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  p100 for variable va100 in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  air_pressure
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim6hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim6hrPt  not found in DR => read it in extra coordinates Table:  height
# Warning: spatial shape corresponding to  longitude|latitude|plev23 for variable va23 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev10 for variable zg10 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev10 for variable ua10 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev23 for variable wap23 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev10 for variable va10 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev23 for variable ta23 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev23 for variable ua23 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev23 for variable zg23 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev23 for variable hus23 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev10 for variable ta10 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev10 for variable hus10 in Table PRIMAVERA_Primday  not found in DR.
# Warning: spatial shape corresponding to  longitude|latitude|plev10 for variable wap10 in Table PRIMAVERA_Primday  not found in DR.
# Info: dimid corresponding to  plev12 for variable zg12 in Table MYPROJECT_Myproday  not found in DR => read it in extra coordinates Table:  air_pressure  100000. 85000. 70000. 50000. 25000. 15000. 10000. 7000. 5000. 1000. 500. 200.
# Number of 'cmor' and 'perso' among home variables:  8
# Number of 'extra' among home variables:  178

# %%
# dict_plevs is a 3-levels intelaced dictionnary containing for each var (key=svar-label_without_psuffix), 
# the list of svar (key=svar-label,value=svar-object) per pressure levels set (key=sdim-label):
# { "varX":
#      { "plevA": {"svar1":svar1,"svar2":svar2,"svar3":svar3},
#        "plevB": {"svar4":svar4,"svar5":svar5},
#        "plevC": {"svar6":svar6} },
#   "varY":
#      { "plevA": {"svar7":svar7},
#        "plevD": {"svar8":svar8,"svar9":svar9} }
# }
dict_plevs={}
for sv in svars:
    for sd in sv.sdims.values():
        if sd.label.startswith("p"): # couvre les dimensions verticales de type 'plev7h' ou 'p850'
            lwps=sv.label_without_psuffix
            sv.sdims[sd.label].is_zoom_of="union_plevs_"+lwps
            if not dict_plevs.has_key(lwps):
                dict_plevs[lwps]={sd.label:{sv.label:sv}}
            else:
                if not dict_plevs[lwps].has_key(sd.label):
                    dict_plevs[lwps].update({sd.label:{sv.label:sv}})
                else:    
                    if sv.label not in dict_plevs[lwps][sd.label].keys(): 
                        dict_plevs[lwps][sd.label].update({sv.label:sv})
                    else:
                        #print sv.label,"in table",sv.mipTable,"already listed for",sd.label
                        pass

# %%
# Checking...
#for k,v in dict_plevs.items(): print k,v

# %%
# Checking...
for sv in svars:
    for sd in sv.sdims.values():
        if sd.label.startswith("p"):
            print "--- ",sv.label
            print "    * ",sd.label,"axis is zoom of",sd.is_zoom_of
# Out:
# ---  ua850
#     *  p850 axis is zoom of union_plevs_ua850
# ---  va200
#     *  p200 axis is zoom of union_plevs_va200
# ---  va850
#     *  p850 axis is zoom of union_plevs_va850
# ---  ua200
#     *  p200 axis is zoom of union_plevs_ua200
# ---  ta
#     *  plev19 axis is zoom of union_plevs_ta
# ---  n2o
#     *  plev19 axis is zoom of union_plevs_n2o
# ---  n2oClim
#     *  plev19 axis is zoom of union_plevs_n2oClim
# ---  ch4
#     *  plev19 axis is zoom of union_plevs_ch4
# ---  hus
#     *  plev19 axis is zoom of union_plevs_hus
# ---  zg
#     *  plev19 axis is zoom of union_plevs_zg
# ---  co2Clim
#     *  plev19 axis is zoom of union_plevs_co2Clim
# ---  wap
#     *  plev19 axis is zoom of union_plevs_wap
# ---  hur
#     *  plev19 axis is zoom of union_plevs_hur
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  o3Clim
#     *  plev19 axis is zoom of union_plevs_o3Clim
# ---  o3
#     *  plev19 axis is zoom of union_plevs_o3
# ---  co2
#     *  plev19 axis is zoom of union_plevs_co2
# ---  ch4Clim
#     *  plev19 axis is zoom of union_plevs_ch4Clim
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  zg
#     *  plev8 axis is zoom of union_plevs_zg
# ---  ua
#     *  plev8 axis is zoom of union_plevs_ua
# ---  ta
#     *  plev8 axis is zoom of union_plevs_ta
# ---  wap
#     *  plev8 axis is zoom of union_plevs_wap
# ---  hus
#     *  plev8 axis is zoom of union_plevs_hus
# ---  hur
#     *  plev8 axis is zoom of union_plevs_hur
# ---  va
#     *  plev8 axis is zoom of union_plevs_va
# ---  ta
#     *  plev19 axis is zoom of union_plevs_ta
# ---  hus
#     *  plev19 axis is zoom of union_plevs_hus
# ---  zg
#     *  plev19 axis is zoom of union_plevs_zg
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  wap
#     *  plev19 axis is zoom of union_plevs_wap
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  zg
#     *  plev8 axis is zoom of union_plevs_zg
# ---  ua
#     *  plev8 axis is zoom of union_plevs_ua
# ---  ta
#     *  plev8 axis is zoom of union_plevs_ta
# ---  wap
#     *  plev8 axis is zoom of union_plevs_wap
# ---  hus
#     *  plev8 axis is zoom of union_plevs_hus
# ---  hur
#     *  plev8 axis is zoom of union_plevs_hur
# ---  va
#     *  plev8 axis is zoom of union_plevs_va
# ---  zg
#     *  plev39 axis is zoom of union_plevs_zg
# ---  clisccp
#     *  plev7c axis is zoom of union_plevs_clisccp
# ---  zg
#     *  plev8 axis is zoom of union_plevs_zg
# ---  ua
#     *  plev8 axis is zoom of union_plevs_ua
# ---  ta
#     *  plev8 axis is zoom of union_plevs_ta
# ---  wap
#     *  plev8 axis is zoom of union_plevs_wap
# ---  hus
#     *  plev8 axis is zoom of union_plevs_hus
# ---  hur
#     *  plev8 axis is zoom of union_plevs_hur
# ---  va
#     *  plev8 axis is zoom of union_plevs_va
# ---  va
#     *  plev3 axis is zoom of union_plevs_va
# ---  wap
#     *  plev3 axis is zoom of union_plevs_wap
# ---  ta
#     *  plev3 axis is zoom of union_plevs_ta
# ---  ua
#     *  plev3 axis is zoom of union_plevs_ua
# ---  jpdftaureliqmodis
#     *  plev7c axis is zoom of union_plevs_jpdftaureliqmodis
# ---  jpdftaureicemodis
#     *  plev7c axis is zoom of union_plevs_jpdftaureicemodis
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  zg
#     *  plev19 axis is zoom of union_plevs_zg
# ---  ta
#     *  plev19 axis is zoom of union_plevs_ta
# ---  wap
#     *  plev19 axis is zoom of union_plevs_wap
# ---  hus
#     *  plev19 axis is zoom of union_plevs_hus
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  jpdftaureicemodis
#     *  plev7c axis is zoom of union_plevs_jpdftaureicemodis
# ---  jpdftaureliqmodis
#     *  plev7c axis is zoom of union_plevs_jpdftaureliqmodis
# ---  clhcalipso
#     *  p220 axis is zoom of union_plevs_clhcalipso
# ---  clmcalipso
#     *  p560 axis is zoom of union_plevs_clmcalipso
# ---  cllcalipso
#     *  p840 axis is zoom of union_plevs_cllcalipso
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  zg
#     *  plev19 axis is zoom of union_plevs_zg
# ---  ta
#     *  plev19 axis is zoom of union_plevs_ta
# ---  wap
#     *  plev19 axis is zoom of union_plevs_wap
# ---  hus
#     *  plev19 axis is zoom of union_plevs_hus
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  epfy
#     *  plev39 axis is zoom of union_plevs_epfy
# ---  utendepfd
#     *  plev39 axis is zoom of union_plevs_utendepfd
# ---  zmtnt
#     *  plev39 axis is zoom of union_plevs_zmtnt
# ---  vtem
#     *  plev39 axis is zoom of union_plevs_vtem
# ---  wtem
#     *  plev39 axis is zoom of union_plevs_wtem
# ---  epfz
#     *  plev39 axis is zoom of union_plevs_epfz
# ---  clisccp
#     *  plev7c axis is zoom of union_plevs_clisccp
# ---  ua
#     *  plev3 axis is zoom of union_plevs_ua
# ---  ta
#     *  plev3 axis is zoom of union_plevs_ta
# ---  va
#     *  plev3 axis is zoom of union_plevs_va
# ---  rv850
#     *  p850 axis is zoom of union_plevs_rv850
# ---  zg1000
#     *  p1000 axis is zoom of union_plevs_zg1000
# ---  clmcalipso
#     *  p560 axis is zoom of union_plevs_clmcalipso
# ---  cllcalipso
#     *  p840 axis is zoom of union_plevs_cllcalipso
# ---  clhcalipso
#     *  p220 axis is zoom of union_plevs_clhcalipso
# ---  oh
#     *  plev39 axis is zoom of union_plevs_oh
# ---  zg
#     *  plev39 axis is zoom of union_plevs_zg
# ---  o3
#     *  plev39 axis is zoom of union_plevs_o3
# ---  bry
#     *  plev39 axis is zoom of union_plevs_bry
# ---  noy
#     *  plev39 axis is zoom of union_plevs_noy
# ---  cly
#     *  plev39 axis is zoom of union_plevs_cly
# ---  ta
#     *  plev39 axis is zoom of union_plevs_ta
# ---  n2o
#     *  plev39 axis is zoom of union_plevs_n2o
# ---  hcl
#     *  plev39 axis is zoom of union_plevs_hcl
# ---  meanage
#     *  plev39 axis is zoom of union_plevs_meanage
# ---  va
#     *  plev39 axis is zoom of union_plevs_va
# ---  ch4
#     *  plev39 axis is zoom of union_plevs_ch4
# ---  hno3
#     *  plev39 axis is zoom of union_plevs_hno3
# ---  ua
#     *  plev39 axis is zoom of union_plevs_ua
# ---  ho2
#     *  plev39 axis is zoom of union_plevs_ho2
# ---  h2o
#     *  plev39 axis is zoom of union_plevs_h2o
# ---  n2o
#     *  plev19 axis is zoom of union_plevs_n2o
# ---  n2oClim
#     *  plev19 axis is zoom of union_plevs_n2oClim
# ---  ch4
#     *  plev19 axis is zoom of union_plevs_ch4
# ---  co2Clim
#     *  plev19 axis is zoom of union_plevs_co2Clim
# ---  hur
#     *  plev19 axis is zoom of union_plevs_hur
# ---  o3Clim
#     *  plev19 axis is zoom of union_plevs_o3Clim
# ---  o3
#     *  plev19 axis is zoom of union_plevs_o3
# ---  co2
#     *  plev19 axis is zoom of union_plevs_co2
# ---  ch4Clim
#     *  plev19 axis is zoom of union_plevs_ch4Clim
# ---  ua
#     *  plev3 axis is zoom of union_plevs_ua
# ---  wap4
#     *  plev4 axis is zoom of union_plevs_wap4
# ---  wbptemp7h
#     *  plev7h axis is zoom of union_plevs_wbptemp7h
# ---  va
#     *  plev3 axis is zoom of union_plevs_va
# ---  hus4
#     *  plev4 axis is zoom of union_plevs_hus4
# ---  tntrl
#     *  plev39 axis is zoom of union_plevs_tntrl
# ---  tntrscs
#     *  plev39 axis is zoom of union_plevs_tntrscs
# ---  tntmp
#     *  plev39 axis is zoom of union_plevs_tntmp
# ---  tntc
#     *  plev39 axis is zoom of union_plevs_tntc
# ---  tntrs
#     *  plev39 axis is zoom of union_plevs_tntrs
# ---  tntscp
#     *  plev39 axis is zoom of union_plevs_tntscp
# ---  tntrlcs
#     *  plev39 axis is zoom of union_plevs_tntrlcs
# ---  tntogw
#     *  plev39 axis is zoom of union_plevs_tntogw
# ---  utendnogw
#     *  plev39 axis is zoom of union_plevs_utendnogw
# ---  utendwtem
#     *  plev39 axis is zoom of union_plevs_utendwtem
# ---  utendvtem
#     *  plev39 axis is zoom of union_plevs_utendvtem
# ---  utendogw
#     *  plev39 axis is zoom of union_plevs_utendogw
# ---  ua
#     *  plev39 axis is zoom of union_plevs_ua
# ---  psitem
#     *  plev39 axis is zoom of union_plevs_psitem
# ---  ta
#     *  plev3 axis is zoom of union_plevs_ta
# ---  ua
#     *  plev3 axis is zoom of union_plevs_ua
# ---  va
#     *  plev3 axis is zoom of union_plevs_va
# ---  epfy
#     *  plev39 axis is zoom of union_plevs_epfy
# ---  utendepfd
#     *  plev39 axis is zoom of union_plevs_utendepfd
# ---  tntnogw
#     *  plev39 axis is zoom of union_plevs_tntnogw
# ---  vtem
#     *  plev39 axis is zoom of union_plevs_vtem
# ---  wtem
#     *  plev39 axis is zoom of union_plevs_wtem
# ---  epfz
#     *  plev39 axis is zoom of union_plevs_epfz
# ---  meanage
#     *  plev39 axis is zoom of union_plevs_meanage
# ---  zg
#     *  plev19 axis is zoom of union_plevs_zg
# ---  ta
#     *  plev19 axis is zoom of union_plevs_ta
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  hus
#     *  plev19 axis is zoom of union_plevs_hus
# ---  wap
#     *  plev19 axis is zoom of union_plevs_wap
# ---  tntsw
#     *  plev19 axis is zoom of union_plevs_tntsw
# ---  utendogw
#     *  plev19 axis is zoom of union_plevs_utendogw
# ---  diabdrag
#     *  plev19 axis is zoom of union_plevs_diabdrag
# ---  utendnogw
#     *  plev19 axis is zoom of union_plevs_utendnogw
# ---  ta7h
#     *  plev7h axis is zoom of union_plevs_ta7h
# ---  zg7h
#     *  plev7h axis is zoom of union_plevs_zg7h
# ---  hus7h
#     *  plev7h axis is zoom of union_plevs_hus7h
# ---  vortmean
#     *  plev3 axis is zoom of union_plevs_vortmean
# ---  ua7h
#     *  plev7h axis is zoom of union_plevs_ua7h
# ---  va7h
#     *  plev7h axis is zoom of union_plevs_va7h
# ---  utendnogw
#     *  plev39 axis is zoom of union_plevs_utendnogw
# ---  vtendnogw
#     *  plev39 axis is zoom of union_plevs_vtendnogw
# ---  ygwdparam
#     *  plev39 axis is zoom of union_plevs_ygwdparam
# ---  xgwdparam
#     *  plev39 axis is zoom of union_plevs_xgwdparam
# ---  tntnogw
#     *  plev39 axis is zoom of union_plevs_tntnogw
# ---  wtem
#     *  plev39 axis is zoom of union_plevs_wtem
# ---  utendepfd
#     *  plev39 axis is zoom of union_plevs_utendepfd
# ---  vtem
#     *  plev39 axis is zoom of union_plevs_vtem
# ---  epfz
#     *  plev39 axis is zoom of union_plevs_epfz
# ---  epfy
#     *  plev39 axis is zoom of union_plevs_epfy
# ---  utendogw
#     *  plev19 axis is zoom of union_plevs_utendogw
# ---  vtendogw
#     *  plev19 axis is zoom of union_plevs_vtendogw
# ---  utendnogw
#     *  plev19 axis is zoom of union_plevs_utendnogw
# ---  vtendnogw
#     *  plev19 axis is zoom of union_plevs_vtendnogw
# ---  ta
#     *  plev39 axis is zoom of union_plevs_ta
# ---  clisccp
#     *  plev7c axis is zoom of union_plevs_clisccp
# ---  cllcalipso
#     *  p840 axis is zoom of union_plevs_cllcalipso
# ---  clisccp
#     *  plev7c axis is zoom of union_plevs_clisccp
# ---  clhcalipso
#     *  p220 axis is zoom of union_plevs_clhcalipso
# ---  clmcalipso
#     *  p560 axis is zoom of union_plevs_clmcalipso
# ---  ta500
#     *  p500 axis is zoom of union_plevs_ta500
# ---  ua850
#     *  p850 axis is zoom of union_plevs_ua850
# ---  ta850
#     *  p850 axis is zoom of union_plevs_ta850
# ---  va850
#     *  p850 axis is zoom of union_plevs_va850
# ---  ua200
#     *  p200 axis is zoom of union_plevs_ua200
# ---  hus850
#     *  p850 axis is zoom of union_plevs_hus850
# ---  va200
#     *  p200 axis is zoom of union_plevs_va200
# ---  rv850
#     *  p850 axis is zoom of union_plevs_rv850
# ---  jpdftaureliqmodis
#     *  plev7c axis is zoom of union_plevs_jpdftaureliqmodis
# ---  jpdftaureicemodis
#     *  plev7c axis is zoom of union_plevs_jpdftaureicemodis
# ---  oxprod
#     *  plev39 axis is zoom of union_plevs_oxprod
# ---  vmrox
#     *  plev39 axis is zoom of union_plevs_vmrox
# ---  jo3
#     *  plev39 axis is zoom of union_plevs_jo3
# ---  oxloss
#     *  plev39 axis is zoom of union_plevs_oxloss
# ---  jo2
#     *  plev39 axis is zoom of union_plevs_jo2
# ---  vtendogw
#     *  plev19 axis is zoom of union_plevs_vtendogw
# ---  vtendnogw
#     *  plev19 axis is zoom of union_plevs_vtendnogw
# ---  ta27
#     *  plev27 axis is zoom of union_plevs_ta27
# ---  hus27
#     *  plev27 axis is zoom of union_plevs_hus27
# ---  rainmxrat27
#     *  plev27 axis is zoom of union_plevs_rainmxrat27
# ---  va27
#     *  plev27 axis is zoom of union_plevs_va27
# ---  snowmxrat27
#     *  plev27 axis is zoom of union_plevs_snowmxrat27
# ---  ua27
#     *  plev27 axis is zoom of union_plevs_ua27
# ---  tntmp27
#     *  plev27 axis is zoom of union_plevs_tntmp27
# ---  cldicemxrat27
#     *  plev27 axis is zoom of union_plevs_cldicemxrat27
# ---  zg27
#     *  plev27 axis is zoom of union_plevs_zg27
# ---  tntrl27
#     *  plev27 axis is zoom of union_plevs_tntrl27
# ---  grplmxrat27
#     *  plev27 axis is zoom of union_plevs_grplmxrat27
# ---  tntrs27
#     *  plev27 axis is zoom of union_plevs_tntrs27
# ---  cldwatmxrat27
#     *  plev27 axis is zoom of union_plevs_cldwatmxrat27
# ---  cldwatmxrat27
#     *  plev27 axis is zoom of union_plevs_cldwatmxrat27
# ---  zg27
#     *  plev27 axis is zoom of union_plevs_zg27
# ---  hus27
#     *  plev27 axis is zoom of union_plevs_hus27
# ---  grplmxrat27
#     *  plev27 axis is zoom of union_plevs_grplmxrat27
# ---  snowmxrat27
#     *  plev27 axis is zoom of union_plevs_snowmxrat27
# ---  pfull27
#     *  plev27 axis is zoom of union_plevs_pfull27
# ---  ta27
#     *  plev27 axis is zoom of union_plevs_ta27
# ---  rainmxrat27
#     *  plev27 axis is zoom of union_plevs_rainmxrat27
# ---  cldicemxrat27
#     *  plev27 axis is zoom of union_plevs_cldicemxrat27
# ---  ta850
#     *  p850 axis is zoom of union_plevs_ta850
# ---  wap500
#     *  p500 axis is zoom of union_plevs_wap500
# ---  ta700
#     *  p700 axis is zoom of union_plevs_ta700
# ---  clisccp
#     *  plev7c axis is zoom of union_plevs_clisccp
# ---  ua
#     *  plev3 axis is zoom of union_plevs_ua
# ---  ta
#     *  plev3 axis is zoom of union_plevs_ta
# ---  va
#     *  plev3 axis is zoom of union_plevs_va
# ---  tntrl
#     *  plev39 axis is zoom of union_plevs_tntrl
# ---  tntrscs
#     *  plev39 axis is zoom of union_plevs_tntrscs
# ---  tntmp
#     *  plev39 axis is zoom of union_plevs_tntmp
# ---  tntc
#     *  plev39 axis is zoom of union_plevs_tntc
# ---  tntrs
#     *  plev39 axis is zoom of union_plevs_tntrs
# ---  tntscp
#     *  plev39 axis is zoom of union_plevs_tntscp
# ---  tntrlcs
#     *  plev39 axis is zoom of union_plevs_tntrlcs
# ---  tntogw
#     *  plev39 axis is zoom of union_plevs_tntogw
# ---  wap500
#     *  p500 axis is zoom of union_plevs_wap500
# ---  ta700
#     *  p700 axis is zoom of union_plevs_ta700
# ---  ta
#     *  plev3 axis is zoom of union_plevs_ta
# ---  wap27
#     *  plev27 axis is zoom of union_plevs_wap27
# ---  vtendnogw27
#     *  plev27 axis is zoom of union_plevs_vtendnogw27
# ---  ta27
#     *  plev27 axis is zoom of union_plevs_ta27
# ---  ua27
#     *  plev27 axis is zoom of union_plevs_ua27
# ---  utendnogw27
#     *  plev27 axis is zoom of union_plevs_utendnogw27
# ---  va27
#     *  plev27 axis is zoom of union_plevs_va27
# ---  zg27
#     *  plev27 axis is zoom of union_plevs_zg27
# ---  tntr27
#     *  plev27 axis is zoom of union_plevs_tntr27
# ---  va
#     *  plev39 axis is zoom of union_plevs_va
# ---  ta
#     *  plev39 axis is zoom of union_plevs_ta
# ---  ua
#     *  plev39 axis is zoom of union_plevs_ua
# ---  hus
#     *  plev39 axis is zoom of union_plevs_hus
# ---  zg
#     *  plev39 axis is zoom of union_plevs_zg
# ---  va7h
#     *  plev7h axis is zoom of union_plevs_va7h
# ---  hus7h
#     *  plev7h axis is zoom of union_plevs_hus7h
# ---  wap7h
#     *  plev7h axis is zoom of union_plevs_wap7h
# ---  ua7h
#     *  plev7h axis is zoom of union_plevs_ua7h
# ---  ta7h
#     *  plev7h axis is zoom of union_plevs_ta7h
# ---  ta
#     *  plev19 axis is zoom of union_plevs_ta
# ---  n2o
#     *  plev19 axis is zoom of union_plevs_n2o
# ---  n2oClim
#     *  plev19 axis is zoom of union_plevs_n2oClim
# ---  ch4
#     *  plev19 axis is zoom of union_plevs_ch4
# ---  hus
#     *  plev19 axis is zoom of union_plevs_hus
# ---  zg
#     *  plev19 axis is zoom of union_plevs_zg
# ---  co2Clim
#     *  plev19 axis is zoom of union_plevs_co2Clim
# ---  wap
#     *  plev19 axis is zoom of union_plevs_wap
# ---  hur
#     *  plev19 axis is zoom of union_plevs_hur
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  o3Clim
#     *  plev19 axis is zoom of union_plevs_o3Clim
# ---  o3
#     *  plev19 axis is zoom of union_plevs_o3
# ---  co2
#     *  plev19 axis is zoom of union_plevs_co2
# ---  ch4Clim
#     *  plev19 axis is zoom of union_plevs_ch4Clim
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  vortmean
#     *  plev7h axis is zoom of union_plevs_vortmean
# ---  ua100
#     *  p100 axis is zoom of union_plevs_ua100
# ---  zg7h
#     *  plev7h axis is zoom of union_plevs_zg7h
# ---  hus1000
#     *  p1000 axis is zoom of union_plevs_hus1000
# ---  hus100
#     *  p100 axis is zoom of union_plevs_hus100
# ---  ta100
#     *  p100 axis is zoom of union_plevs_ta100
# ---  va100
#     *  p100 axis is zoom of union_plevs_va100
# ---  va1000
#     *  p1000 axis is zoom of union_plevs_va1000
# ---  ua1000
#     *  p1000 axis is zoom of union_plevs_ua1000
# ---  hus4
#     *  plev4 axis is zoom of union_plevs_hus4
# ---  ua4
#     *  plev4 axis is zoom of union_plevs_ua4
# ---  va4
#     *  plev4 axis is zoom of union_plevs_va4
# ---  hus1000
#     *  p1000 axis is zoom of union_plevs_hus1000
# ---  va1000
#     *  p1000 axis is zoom of union_plevs_va1000
# ---  ua1000
#     *  p1000 axis is zoom of union_plevs_ua1000
# ---  zg19
#     *  plev19 axis is zoom of union_plevs_zg19
# ---  va23
#     *  plev23 axis is zoom of union_plevs_va23
# ---  zg10
#     *  plev10 axis is zoom of union_plevs_zg10
# ---  ua10
#     *  plev10 axis is zoom of union_plevs_ua10
# ---  hus19
#     *  plev19 axis is zoom of union_plevs_hus19
# ---  ua19
#     *  plev19 axis is zoom of union_plevs_ua19
# ---  wap23
#     *  plev23 axis is zoom of union_plevs_wap23
# ---  va10
#     *  plev10 axis is zoom of union_plevs_va10
# ---  wap19
#     *  plev19 axis is zoom of union_plevs_wap19
# ---  ta23
#     *  plev23 axis is zoom of union_plevs_ta23
# ---  ua23
#     *  plev23 axis is zoom of union_plevs_ua23
# ---  zg23
#     *  plev23 axis is zoom of union_plevs_zg23
# ---  va19
#     *  plev19 axis is zoom of union_plevs_va19
# ---  hus23
#     *  plev23 axis is zoom of union_plevs_hus23
# ---  ta10
#     *  plev10 axis is zoom of union_plevs_ta10
# ---  hus10
#     *  plev10 axis is zoom of union_plevs_hus10
# ---  ta19
#     *  plev19 axis is zoom of union_plevs_ta19
# ---  wap10
#     *  plev10 axis is zoom of union_plevs_wap10
# ---  va
#     *  plev19 axis is zoom of union_plevs_va
# ---  ua
#     *  plev19 axis is zoom of union_plevs_ua
# ---  va
#     *  plev39 axis is zoom of union_plevs_va
# ---  epfluxdiv
#     *  plev39 axis is zoom of union_plevs_epfluxdiv
# ---  zg
#     *  plev39 axis is zoom of union_plevs_zg
# ---  vstarbar
#     *  plev39 axis is zoom of union_plevs_vstarbar
# ---  wstarbar
#     *  plev39 axis is zoom of union_plevs_wstarbar
# ---  xnonoroggwdparam
#     *  plev39 axis is zoom of union_plevs_xnonoroggwdparam
# ---  ua
#     *  plev39 axis is zoom of union_plevs_ua
# ---  ynonoroggwdparam
#     *  plev39 axis is zoom of union_plevs_ynonoroggwdparam
# ---  zg12
#     *  plev12 axis is zoom of union_plevs_zg12

# %%
# Create xios axis for union of plevs
printout=False
for lwps in dict_plevs.keys():
    sdim_union=simple_Dim()
    if printout: print "--- Label without suffix:",lwps
    plevs_union_xios=""
    plevs_union=set()
    for plev in dict_plevs[lwps].keys():  
        plev_values=[]
        for svar in dict_plevs[lwps][plev].values(): 
            if not plev_values:
                # svar is the first one with this plev => get its level values
                # mpmoine_note: on reecrase les attributs de sdim_union à chaque nouveau plev. Pas utile mais
                # mpmoine_note: c'est la facon la plus simple de faire
                sdsv=svar.sdims[plev]
                if sdsv.stdname:   sdim_union.stdname=sdsv.stdname
                if sdsv.long_name: sdim_union.long_name=sdsv.long_name
                if sdsv.positive:  sdim_union.positive=sdsv.positive
                if sdsv.out_name:  sdim_union.out_name=sdsv.out_name
                if sdsv.units:     sdim_union.units=sdsv.units
                # case of multi pressure levels
                plev_values=set(sdsv.requested.split())
                if not plev_values:
                    # case of single pressure level
                    plev_values=set(sdsv.value.split())
                plevs_union=plevs_union.union(plev_values)
                if printout: print "    -- on",plev,":",plev_values 
            if printout: print "       *",svar.label,"(",svar.mipTable,")"
    
    list_plevs_union=list(plevs_union)
    list_plevs_union.sort(reverse=True)
    for lev in list_plevs_union: plevs_union_xios+=" "+lev
    if printout: print ">>> XIOS plevs union:", plevs_union_xios
    # mpmoine_note: on ecrase le label et requested par les valeurs de l'union
    sdim_union.label="union_plevs_"+lwps
    sdim_union.requested=plevs_union_xios
    axis_def=create_axis_def(sdim_union,settings["ping_variables_prefix"])
    print axis_def
# Out:
# <axis id="union_plevs_zg19" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg12" positive="down" n_glo="12" value="(0,12) [ 85000. 70000. 7000. 50000. 5000. 500. 25000. 200. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg10" positive="down" n_glo="10" value="(0,10) [ 85000. 70000. 7000. 50000. 5000. 25000. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua200" positive="down" n_glo="1" value="(0,1) [ 20000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua10" positive="down" n_glo="10" value="(0,10) [ 85000. 70000. 7000. 50000. 5000. 25000. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua19" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_rainmxrat27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va23" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va10" positive="down" n_glo="10" value="(0,10) [ 85000. 70000. 7000. 50000. 5000. 25000. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus100" positive="down" n_glo="1" value="(0,1) [ 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_cly" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wbptemp7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_rv850" positive="down" n_glo="1" value="(0,1) [ 85000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua100" positive="down" n_glo="1" value="(0,1) [ 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_utendogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_noy" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_co2Clim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_grplmxrat27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_utendnogw27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta700" positive="down" n_glo="1" value="(0,1) [ 70000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_xgwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntrs27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntmp27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_psitem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_jo2" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_jo3" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap4" positive="down" n_glo="4" value="(0,4) [ 92500. 85000. 50000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_utendepfd" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_clmcalipso" positive="down" n_glo="1" value="(0,1) [ 56000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_diabdrag" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus850" positive="down" n_glo="1" value="(0,1) [ 85000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_co2" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua850" positive="down" n_glo="1" value="(0,1) [ 85000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap500" positive="down" n_glo="1" value="(0,1) [ 50000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wstarbar" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ch4Clim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta23" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_o3" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hcl" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vortmean" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntc" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vtendnogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_epfy" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus4" positive="down" n_glo="4" value="(0,4) [ 92500. 85000. 50000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntrlcs" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_epfz" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vtendogw" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_utendvtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntscp" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta10" positive="down" n_glo="10" value="(0,10) [ 85000. 70000. 7000. 50000. 5000. 25000. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_oh" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta19" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vstarbar" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap19" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_utendwtem" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntnogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap10" positive="down" n_glo="10" value="(0,10) [ 85000. 70000. 7000. 50000. 5000. 25000. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_n2oClim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_bry" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntrs" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta100" positive="down" n_glo="1" value="(0,1) [ 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_oxprod" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntrl" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua4" positive="down" n_glo="4" value="(0,4) [ 92500. 85000. 50000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ygwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap23" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hno3" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va100" positive="down" n_glo="1" value="(0,1) [ 10000.]" name="plev" standard_name="air_pressure" long_name="pressure" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_clisccp" positive="down" n_glo="7" value="(0,7) [ 90000. 9000. 74000. 62000. 50000. 37500. 24500.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_wap" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va850" positive="down" n_glo="1" value="(0,1) [ 85000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntmp" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hur" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta500" positive="down" n_glo="1" value="(0,1) [ 50000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntr27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntrscs" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus1000" positive="down" n_glo="1" value="(0,1) [ 100000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_xnonoroggwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua23" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ch4" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va200" positive="down" n_glo="1" value="(0,1) [ 20000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg1000" positive="down" n_glo="1" value="(0,1) [ 100000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zmtnt" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ta850" positive="down" n_glo="1" value="(0,1) [ 85000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va4" positive="down" n_glo="4" value="(0,4) [ 92500. 85000. 50000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_n2o" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_oxloss" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_cldwatmxrat27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus10" positive="down" n_glo="10" value="(0,10) [ 85000. 70000. 7000. 50000. 5000. 25000. 15000. 100000. 10000. 1000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_pfull27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va7h" positive="down" n_glo="7" value="(0,7) [ 92500. 85000. 70000. 60000. 50000. 5000. 25000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus19" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va1000" positive="down" n_glo="1" value="(0,1) [ 100000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_o3Clim" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_snowmxrat27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_epfluxdiv" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vmrox" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_vtendnogw27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntrl27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_utendnogw" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ua1000" positive="down" n_glo="1" value="(0,1) [ 100000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_cldicemxrat27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_jpdftaureliqmodis" positive="down" n_glo="7" value="(0,7) [ 90000. 9000. 74000. 62000. 50000. 37500. 24500.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_zg23" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_tntsw" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus27" positive="down" n_glo="27" value="(0,27) [ 97500. 95000. 92500. 90000. 87500. 85000. 82500. 80000. 77500. 75000. 70000. 65000. 60000. 55000. 50000. 45000. 40000. 35000. 30000. 25000. 22500. 20000. 17500. 15000. 12500. 100000. 10000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_hus23" positive="down" n_glo="23" value="(0,23) [ 92500. 85000. 70000. 7000. 700. 60000. 50000. 5000. 500. 40000. 40. 30000. 3000. 300. 25000. 20000. 2000. 200. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_meanage" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_jpdftaureicemodis" positive="down" n_glo="7" value="(0,7) [ 90000. 9000. 74000. 62000. 50000. 37500. 24500.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_h2o" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ho2" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_ynonoroggwdparam" positive="down" n_glo="39" value="(0,39) [ 92500. 9000. 85000. 8000. 70000. 7000. 700. 70. 7. 60000. 50000. 5000. 500. 50. 5. 40000. 40. 30000. 3000. 300. 30. 3. 25000. 20000. 2000. 200. 20. 17000. 15000. 1500. 150. 15. 13000. 11500. 100000. 10000. 1000. 100. 10.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_clhcalipso" positive="down" n_glo="1" value="(0,1) [ 22000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_cllcalipso" positive="down" n_glo="1" value="(0,1) [ 84000.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>
# <axis id="union_plevs_va19" positive="down" n_glo="19" value="(0,19) [ 92500. 85000. 70000. 7000. 60000. 50000. 5000. 500. 40000. 30000. 3000. 25000. 20000. 2000. 15000. 100000. 10000. 1000. 100.]" name="plev" standard_name="air_pressure" long_name="False" unit="Pa">
# 		<interpolate_axis type="polynomial" order="1" coordinate="CMIP6_pfull"/>
# 	</axis>

# %%
import re
values=[85000.,50000.,0.]
s="850"
print any (s in str(v) for v in values)
# Out:
# True

# %%
for sv in svars:
    for d in sv.sdims.values():
        print "***",d.label,"***"
# Out:
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** latitude ***
# *** p850 ***
# *** longitude ***
# *** latitude ***
# *** p200 ***
# *** longitude ***
# *** latitude ***
# *** p850 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** p200 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** alevhalf ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** alevhalf ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** sdepth1 ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevel ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** alevel ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevel ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** site ***
# *** alevel ***
# *** site ***
# *** alevhalf ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** site ***
# *** site ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** site ***
# *** site ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** site ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** site ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** site ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** basin ***
# *** rho ***
# *** latitude ***
# *** basin ***
# *** rho ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** basin ***
# *** rho ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** rho ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** siline ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** siline ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** siline ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typesever ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typesdec ***
# *** longitude ***
# *** latitude ***
# *** typepdec ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth1 ***
# *** longitude ***
# *** latitude ***
# *** typepever ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typec3pft ***
# *** longitude ***
# *** latitude ***
# *** typebare ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typec4pft ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** depth300m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth700m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth2000m ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typesever ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typec4pft ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typebare ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typesdec ***
# *** longitude ***
# *** latitude ***
# *** typepdec ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth1 ***
# *** longitude ***
# *** latitude ***
# *** typepever ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** typec3pft ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth1 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev7c ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** basin ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** sdepth1 ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev8 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev3 ***
# *** longitude ***
# *** latitude ***
# *** plev3 ***
# *** longitude ***
# *** latitude ***
# *** plev3 ***
# *** longitude ***
# *** latitude ***
# *** plev3 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** ygre ***
# *** xgre ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth100m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** depth0m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** depth300m ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# ...
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** yant ***
# *** xant ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** alevhalf ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** alevhalf ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** height2m ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** p100 ***
# *** longitude ***
# *** latitude ***
# *** plev7h ***
# *** longitude ***
# *** latitude ***
# *** p1000 ***
# *** longitude ***
# *** latitude ***
# *** p100 ***
# *** longitude ***
# *** latitude ***
# *** p100 ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** p100 ***
# *** longitude ***
# *** latitude ***
# *** p1000 ***
# *** longitude ***
# *** latitude ***
# *** p1000 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** height10m ***
# *** longitude ***
# *** latitude ***
# *** plev4 ***
# *** longitude ***
# *** latitude ***
# *** plev4 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** plev4 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height100m ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** p1000 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** height50m ***
# *** longitude ***
# *** latitude ***
# *** p1000 ***
# *** longitude ***
# *** latitude ***
# *** p1000 ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** olevel ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** basin ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev23 ***
# *** longitude ***
# *** latitude ***
# *** plev10 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev10 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev23 ***
# *** longitude ***
# *** latitude ***
# *** plev10 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev23 ***
# *** longitude ***
# *** latitude ***
# *** plev23 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev23 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** sdepth ***
# *** longitude ***
# *** latitude ***
# *** plev23 ***
# *** longitude ***
# *** latitude ***
# *** plev10 ***
# *** longitude ***
# *** latitude ***
# *** plev10 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev10 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** plev19 ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** longitude ***
# *** alevel ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev39 ***
# *** latitude ***
# *** plev12 ***
# *** longitude ***
