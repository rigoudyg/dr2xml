# %% [markdown]
# # An example for generating the XIOS file_def for a given lab, model, experiment, year and XIOS context

# %%
#--- Select your laboratory: 'cnrm', 'cerfacs' or'ipsl'
lab='cerfacs' 
#--- Select your model type: 'GCM' or 'ESM'
mod='GCM'
#--- Select your molde resolution: 'LR' or 'HR'
resol='LR'

# %% [markdown]
# ## 1. Define the settings specific to the laboratory and the model

# %%
if lab=='cnrm' or lab=='cerfacs':
    #
    #--- Sizes of oce and atm grids ['nho','nlo','nha','nla','nlas','nls','nh1'] (cf DR doc)
    if resol=="LR": actual_sizes=[292*362,75,128*256,91,30,14,128]
    if resol=="HR": actual_sizes=[1442*1021,75,720*360,91,30,14,128]
    #--- Model name like declared to the CMIP6 WIP panel
    if mod=='GCM'and resol=='LR':
        actual_source_id="CNRM-CM6-1"
    if mod=='GCM'and resol=='HR':
        actual_source_id="CNRM-CM6-1-HR"
    if mod=='ESM'and resol=='LR':
        actual_source_id="CNRM-ESM2-1"
    if mod=='ESM'and resol=='HR':
        actual_source_id="CNRM-ESM2-1-HR"   
    #
    lab_and_model_settings={
        #
        "institution_id": "CNRM-CERFACS",
        #"institution": "CNRM, blabla...; CERFACS, blabla...", # institution should be read in CMIP6_CV, if up-to-date
        #
        #--- entry 'source_types' allows to describe, using CMIP6 CV, the various model configurations
        #--- for the lab; This can be superseded by an entry 'source_type' either just below or in dict  
        #--- for simulation settings (further below)
        "source_types" : { "CNRM-CM6-1" : "AOGCM", "CNRM-CM6-1-HR" : "AOGCM", 
                           "CNRM-ESM2-1": "ESM"  , "CNRM-ESM2-1-HR": "ESM" },
        #
        "source_id"      : actual_source_id,
        #"source"         : "CNRM-CM6-1 blabla...", # Useful only if CMIP6_CV is not up-to-date for the source_id
        #--- You may override here the source_type value deduced from source_id and sources_type
        #"source_type" : "AER"  
        #
        #--- references & contact
        #"references"    :  "Blabla...", # A character string containing a list of published or web-based
                                         # references that describe the data or the methods used to produce it.
                                         # Typically, the user should provide references describing the model
                                         # formulation here
        "info_url"      : "http://www.umr-cnrm.fr/cmip6/",
        "contact"       : 'contact.cmip@cnrm.fr',
        #
        #--- We account for the list of MIPS in which the lab takes part.
        #--- Note : a MIPs set limited to {'C4MIP'} leads to a number of tables and 
        #--- variables which is manageable for eye inspection
        "mips_all" : {'AerChemMIP','C4MIP','CFMIP','DAMIP', 'FAFMIP' , 'GeoMIP','GMMIP','ISMIP6',\
                          'LS3MIP','LUMIP','OMIP','PMIP','RFMIP','ScenarioMIP','CORDEX','SIMIP'},
        "mips" : {'C4MIP', 'SIMIP', 'OMIP', 'CFMIP', 'RFMIP'} , 
        #
        #--- Max variable priority level to be output
        "max_priority" : 1,
        "tierMax"      : 3,
        #
        #--- The ping file defines variable names, which are constructed using CMIP6 "MIPvarnames" 
        #--- and a prefix which must be set here, and can be the empty string :
        "ping_variables_prefix" : "CMIP6_",
        #        
        #--- mpmoine_amelioration: pour ecrire un ts_prefix
        #'output_path' : "@IOXDIR@/%file_name%",
        'output_path' : "@IOXDIR@/",
        #
        #--- We account for a list of variables which the lab does not want to produce , 
        #--- oragnized by realms
        #"excluded_vars_file":"./input/excluded_vars/non_published_variables.txt",
        # mpmoine_note: exclusion des variables Cloud Simulator tant que pas activé
        "excluded_vars" : ["clcalipso","clcalipso2","clhcalipso","clcalipsoice","clcalipsoliq", \
                           "cllcalipso","clmcalipso","cltcalipso",\
                           "cfadLidarsr532","cfadDbze94","cfadLidarsr532","clisccp","cltisccp",\
                           "climodis","clwmodis","jpdftaureicemodis","cltmodis","clmisr","parasolRefl"],
        #        
        #--- mpmoine_next_modif: ignore some spatial shapes
        #mpmoine_note: grilles Groenland, Antarctic et les profils en Sites (pas encore codé dans dr2xml)
        "excluded_spshapes": ["XYA-na","XYG-na","S-na","S-AH","S-A","na-A"],
        #
        #--- We account for a list of variables which the lab wants to produce in some cases
        "listof_home_vars":None,
        #        
        #--- mpmoine_last_modif: Path for extra Tables
        "path_extra_tables":None,
        #        
        #--- mpmoine_correction: Path for natives XIOS xml files to parse
        "path_to_parse":"./input_labs/cnrm/to_parse/for_arpege_grid",
        #
        # Each XIOS  context does adress a number of realms
        "realms_per_context" : { 'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'] ,
                              'arpsfx' : ['atmos', 'atmos atmosChem', 'aerosol', 'atmos land', 'land',
                                            'landIce land',  'aerosol land','land landIce',  'landIce', ],
                              }, 
        #
        #--- Some variables, while belonging to a realm, may fall in another XIOS context than the 
        #--- context which handles that realm
        "orphan_variables" : { 'nemo' : ['dummy_variable_for_illustration_purpose'],
                               'arpsfx' : [],
                               },
        "vars_OK" : dict(),
        #        
        #--- A per-variable dict of comments valid for all simulations
        "comments"     : {
            'tas' : 'nothing special about tas'
            },
        #
        #--- Sizes of oce and atm grids ['nho','nlo','nha','nla','nlas','nls','nh1'] (cf DR doc)
        "sizes"  : actual_sizes,
        #
        #--- What is the maximum size of generated files, in number of float values
        "max_file_size_in_floats" : 500.*1.e+6 ,
        #        
        #--- grid_policy among None, DR, native, native+DR, adhoc- see docin grids.py 
        "grid_policy" : "adhoc",
        #        
        #--- Grids : CMIP6 name, name_of_target_domain, CMIP6-std resolution, and description
        "grids" : { 
          "LR"    : {
            "arpsfx" : [ "gr","complete" , "250 km", "data regridded to a T127 gaussian grid (128x256 latlon) from a native atmosphere T127l reduced gaussian grid"] ,
              "nemo" : [ "gn", ""        , "100 km" , "native ocean tri-polar grid with 105 k ocean cells" ],},
          "HR"    : {
            "arpsfx" : [ "gr","completeHR", "50 km", "data regridded to a 359 gaussian grid (180x360 latlon) from a native atmosphere T359l reduced gaussian grid"] ,
              "nemo" : [ "gn", ""         , "25 km" , "native ocean tri-polar grid with 1.47 M ocean cells" ],},
        },
        "grid_choice" : { "CNRM-CM6-1" : "LR", "CNRM-CM6-1-HR" : "HR", "CNRM-ESM2-1": "LR"  , "CNRM-ESM2-1-HR": "HR" },
        #        
        #--- mpmpoine_next_modif: Model component Time steps (min)
        "model_timestep" : { "arpsfx":900., "nemo":900.},
        #        
        #--- mpmoine_amelioration: booleen pour activer ou non l'usage des union/zoom
        #--- Say if you want to use XIOS union/zoom axis to optimize vertical interpolation requested by the DR
        "use_union_zoom" : False
        #        
        }

# %%
if lab=='cerfacs':
    changes={
        "mips"                : 'HighResMIP',
        "max_priority"        : 2,
        "listof_home_vars"    : "./input_labs/cerfacs/home_vars/listof_primavera_extra_vars.txt",
        #"listof_home_vars"    : "./input_labs/cerfacs/home_vars/listof_test_extra_vars.txt",
        "path_extra_tables"   : "./input_labs/cerfacs/extra_Tables",
        #"path_to_parse"       : "./input_labs/cerfacs/to_parse/for_arpege_grid_dr2xml_"+resol+"_STMARTIN_EXCLUPLEV",
        #"path_to_parse"       : "./input_labs/cerfacs/to_parse/for_arpege_grid_dr2xml_"+resol+"_STMARTIN",
        #"path_to_parse"       : "./input_labs/cerfacs/to_parse/for_arpege_grid_dr2xml_"+resol+"_TEST",
        "path_to_parse"       : "./input_labs/cerfacs/to_parse/for_toy_grid_"+resol,
        "grids" : { 
          "LR"    : {
            "arpsfx" : [ "gn","gaussian-reduced_LR" ,"250 km", "native atmosphere T127l reduced gaussian grid"] ,
              "nemo" : [ "gn", ""        , "100 km" , "native ocean tri-polar grid ORCA1 with 105 k ocean cells" ],},
          "HR"    : {
            "arpsfx" : [ "gn","gaussian-reduced_HR", "50 km", "native atmosphere T359l reduced gaussian grid"] ,
              "nemo" : [ "gn", ""         , "25 km" , "native ocean tri-polar grid ORCA025 with 1.47 M ocean cells" ],},
        },
        'comments'            : {},
        'contact'             : 'contact.cmip6@cerfacs.fr',
        "excluded_spshapes"   : ["XYA-na","XYG-na","S-na","S-AH","S-A","na-A"]
                                 #"Y-P19","Y-P39","XY-P19","XY-P27","XY-P3","XY-P4","XY-P7","XY-P7T","XY-P8"]
        }
    lab_and_model_settings.update(changes)

# %%
if lab=='ipsl':
    lab_and_model_settings={
        #        
        "institution_id" : "IPSL",
        #"institution": "IPSL, blabla...", # institution should be read in CMIP6_CV, if up-to-date
        "source_id"      : "IPSL-CM6-1", 
        #"source"         : "IPSL-CM6-1 blabla...", # Useful only if CMIP6_CV is not up-to-date for the source_id
        #--- You may override here the source_type value deduced from source_id and sources_type
        #"source_type" : "AER"  
        #        
        #--- The description of lab models, in CMIP6 CV wording
        "source_types" : { "IPSL-CM6-1" : "AOGCM", "IPSL-CM6-1-HR" : "AOGCM", 
                           "IPSL-ESM2-1": "ESM"  , "IPSL-ESM2-1-HR": "ESM" },
        "source"         : "IPSL-CM6-1", # Useful only if CMIP6_CV is not up to date
        #
        #--- references & contact
        #"references"    :  "Blabla...", # A character string containing a list of published or web-based
                                         # references that describe the data or the methods used to produce it.
                                         # Typically, the user should provide references describing the model
                                         # formulation here
        "info_url"      : "http://www.blabla",
        "contact"       : 'blabla@blabla.fr',
        #
        #--- We account for the list of MIPS in which the lab takes part.
        #--- Note : a MIPs set limited to {'C4MIP'} leads to a number of tables and 
        #--- variables which is manageable for eye inspection
        "mips_for_test": {'C4MIP', 'SIMIP', 'OMIP', 'CFMIP', 'RFMIP'} , 
        "mips" : {'AerChemMIP','C4MIP','CFMIP','DAMIP', 'FAFMIP' , 'GeoMIP','GMMIP','ISMIP6',\
                          'LS3MIP','LUMIP','OMIP','PMIP','RFMIP','ScenarioMIP','CORDEX','SIMIP'},
        #        
        #--- Max variable priority level to be output
        'max_priority' : 1,
        'tierMax'      : 1,
        #
        #--- The ping file defines variable names, which are constructed using CMIP6 "MIPvarnames" 
        #--- and a prefix which must be set here, and can be the empty string :
        "ping_variables_prefix" : "CMIP6_",
        #        
        #--- mpmoine_amelioration: pour ecrire un ts_prefix
        'output_path' : None,
        #
        #--- We account for a list of variables which the lab does not want to produce , 
        #--- Names must match DR MIPvarnames (and **NOT** CF standard_names)
        "excluded_vars_file":None,
        # mpmoine_note: exclusion des variables Cloud Simulator tant que pas activé
        "excluded_vars" : ["clcalipso","clcalipso2","clhcalipso","clcalipsoice","clcalipsoliq", \
                           "cllcalipso","clmcalipso","cltcalipso",\
                           "cfadLidarsr532","cfadDbze94","cfadLidarsr532","clisccp","cltisccp",\
                           "climodis","clwmodis","jpdftaureicemodis","cltmodis","clmisr","parasolRefl"],
        #--- mpmoine_next_modif: ignore some spatial shapes
        #mpmoine_note: grilles Groenland, Antarctic et les profils en Sites (pas encore codé dans dr2xml)
        "excluded_spshapes":["XYA-na","XYG-na","S-na","S-AH","S-A","na-A"],
        #
        #--- We account for a list of variables which the lab wants to produce in some cases
        "listof_home_vars":None,
        #        
        #--- mpmoine_last_modif: Path for extra Tables
        "path_extra_tables":None,
        #        
        #--- mpmoine_correction: Path for natives XIOS xml files to parse
        "path_to_parse":"./input_labs/ipsl/to_parse",
        #
        #--- Each XIOS  context does adress a number of realms
        "realms_per_context" : { 
            'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'],
            'lmdz' : ['atmos', 'atmos land'] , 
            'orchidee': ['land', 'landIce land',  'land landIce', 'landIce'] ,
                              }, 
        #        
        #--- Some variables, while belonging to a realm, may fall in another XIOS context than the 
        #--- context which hanldes that realm
        "orphan_variables" : { 
            'nemo' : [],
            'lmdz' : [],
            'orchidee' : [],
                             },
        "vars_OK" : dict(),
        #        
        #--- A per-variable dict of comments valid for all simulations
        "comments"     : {
            'tas' : 'nothing special about tas'
            },
        #        
        #--- Sizes for atm and oce grids ['nho','nlo','nha','nla','nlas','nls','nh1'] (cf DR doc)
        "sizes"  : [259200,60,64800,40,20,5,100],
        #        
        #--- What is the maximum size of generated files, in number of float values
        "max_file_size_in_floats" : 500.*1.e+6 ,
        #        
        #--- Grids : CMIP6 name, name_of_target_domain, CMIP6-std resolution, and description
        "grids" : { 
          "LR"    : {
            "lmdz" :     [ "gr","" , "??? km", "LMDZ grid"] ,
            "nemo" :     [ "gn", ""        , "100 km" , "native ocean tri-polar grid with 105 k ocean cells" ],
            "orchidee" : [ "gr","" , "??? km", "LMDZ grid"],},
        },
        "grid_choice" : { "IPSL-CM6-1" : "LR", "IPSL-CM6-1-HR" : "HR",
                          "IPSL-ESM2-1": "LR"  , "IPSL-ESM2-1-HR": "HR" },
        #        
        #--- mpmpoine_next_modif: Model component Time steps (min)
        "model_timestep" : { "nemo":60., "lmdz":60.,"orchidee":60.},
        #        
        #--- mpmoine_amelioration: booleen pour activer ou non l'usage des union/zoom
        #--- Say if you want to use XIOS union/zoom axis to optimize vertical interpolation requested by the DR
        "use_union_zoom" : False
        #
    }

# %% [markdown]
# ## 2. Define the settings for the processed simulation

# %%
    simulation_settings={    
        #--- Dictionnary describing the necessary attributes for a given simulation
        #--- Warning : some lines are commented out in this example but should be 
        #--- un-commented in some cases. See comments
        #
        "experiment_id"  : "historical",
        #
        #"contact"        : "", set it only if it is specific to the simualtion
        "project"         : "CMIP6",  #CMIP6 is the default
        #
        #"source_type"    : "ESM" # If source_type is special only for this experiment (e.g. : AMIP)
                                  #(i.e. not the same as in lab_and_model settings), you may tell that here
        #
        #--- MIP specifying the experiment. For historical, it is CMIP6 itself
        #--- In a few cases it may be appropriate to include multiple activities in the activity_id 
        #--- (with multiple activities allowed, separated by single spaces).  
        #--- An example of this is “LUMIP AerChemMIP” for one of the land-use change experiments.
        "activity_id"       : "CMIP", # examples : “PMIP”, “LS3MIP LUMIP”; default is "CMIP"
    
        #--- It is recommended that some description be included to help identify major differences among variants, 
        #--- but care should be taken to record correct information.  Prudence dictates that this attribute includes 
        #--- a warning along the following lines:  “Information provided by this attribute may in some cases be flawed.#
        #--- Users can find more comprehensive and up-to-date documentation via the further_info_url global attribute.”
        "variant_info"      : "Start date chosen so that variant r1i1p1f1 has the better fit with Krakatoa impact on tos",
        #
        #--- 'variant_label' attribute is built gluing <r><i><p><f> values
        "realization_index"    : 1, # Value may be omitted if = 1
        "initialization_index" : 1, # Value may be omitted if = 1
        "physics_index"        : 1, # Value may be omitted if = 1
        "forcing_index"        : 1, # Value may be omitted if = 1
        #
        #--- All about the parent experiment and branching scheme
        "parent_experiment_id" : "piControl",  # Optional, default is False. Omit it (or set it to 'no parent') if not applicable
                                               # Others parent and branch attributes will be disregarded if omitted or set to 'no parent'
                                               # but will be required id parent_experiment_id is defined.
        #                             
        "parent_mip_era"       : 'CMIP5',      # Optional, default is 'mip_era'. Only in special cases (e.g. PMIP warm start from CMIP5/PMIP3 experiment)
        "parent_activity_id"   : 'CMIP',       # Optional, default is 'activity_id'. Only in special cases, defaults to CMIP
        "parent_source_id"     : 'CNRM-CM5.1', # Optional, default is 'source_id'. Only in special cases, where parent model is not the same model
        #"parent_time_ref_year" : '1950'       # Optional, default is '1850'. Is used to build 'parent_time_units'
        #"parent_time_units"    : "days sice 1950-31-12 00:00:00"  # Default is 'days since <parent_time_ref_year>-01-01 00:00:00'.   # Default is ???. In case it is not the same as child time units
        #"parent_variant_label" : "r3i1p1f2"   # Optional, default is 'variant label'. Other cases should be expceptional
        "branch_method"        : "standard",   # Optional, default is 'standard'. Meaning ~ "select a start date" 
        "branch_time_in_parent": "365.0D0",    # Optional, default is False. A double precision value, in parent time units 
        "branch_time_in_child" : "0.0D0",      # Optional, default is False. a double precision value, in child time units 
        #
        #--- mpmoine_cmor_update: CMOR3.2.3 impose 'none' comme default values pour sub_experiment_id et sub_experiment
        "sub_experiment_id"    : "none", # Optional, default is 'none'; example : s1960. 
        "sub_experiment"       : "none", # Optional, default in 'none'
        "history"              : "none", #Used when a simulation is re-run, an output file is modified ....
        #        
        #--- A per-variable dict of comments which are specific to this simulation. It will replace  
        #--- the all-simulation comment present in lab_and_model_settings
        'comments'     : {
            'tas' : 'tas diagnostic uses a special scheme in this simulation',
            }
        }

# %%
if lab=='cerfacs': 
    changes={    
        "experiment_id"        : "Forced-Atmos-Land",
        "source_type"          : "AGCM", # If source_type is special only for this experiment (e.g. : AMIP)
                                  #(i.e. not the same as in lab_and_model settings), you may tell that here
        "activity_id"          : "HighResMIP", # examples : “PMIP”, “LS3MIP LUMIP”; defaults is "CMIP"
        "realization_index"    : 1, # Value may be omitted if = 1
        "initialization_index" : 1, # Value may be omitted if = 1
        "physics_index"        : 1, # Value may be omitted if = 1
        "forcing_index"        : 1, # Value may be omitted if = 1
        "parent_experiment_id" : "no parent", # Optional, default is False. Omit this setting (or set it to 'no parent') if not applicable
                                              # Others parent and branch attributes will be disregarded if omitted or set to 'no parent'
                                              # but will be required id parent_experiment_id is defined.
        #"variant_info"         : "Petite variation en Re mineur",
        "variant_info"         : "none",
        'comments'             : {}
        }
    simulation_settings.update(changes)

# %%
#--- Path to local copy of CMIP6 CVs, which you can get from https://github.com/WCRP-CMIP/CMIP6_CVs
if lab=='cnrm':
    my_cvspath="/cnrm/est/USERS/senesi/public/CMIP6/data_request/CMIP6_CVs/"
elif lab=='cerfacs':
    my_cvspath="/Users/moine/Codes/MyDevel_Codes/CMIP6_DATA_SUITE/CMIP6_CVs/"
elif lab=='ipsl':
    my_cvspath="/ccc/cont003/home/gencmip6/p86caub/CMIP6_DR_DR2XML/CMIP6_CVs/"
my_cvspath="/Users/moine/Codes/MyDevel_Codes/CMIP6_DATA_SUITE/CMIP6_CVs/"

# %% [markdown]
# ## 3. Generate a first file-def with a dummy ping-file, including dummies

# %%
note="VERSIONS:"
print note
print "-"*len(note)

from dr2xml import generate_file_defs
# Out:
# VERSIONS:
# ---------
# * dr2xml version: mpmoine-dev3 = mpmoine-dev2 merged with senesi-dev-v0.12 + updates untill 05/05/2017
# * CMIP6 Data Request version:  01.00.08

# %%
note="\nLAB AND MODEL SETTINGS:"
print note
print "-"*len(note)

for k,v in lab_and_model_settings.items():
    print "* ",k,"=",v
    
note="\nSIMULATION SETTINGS:"
print note
print "-"*len(note)

for k,v in simulation_settings.items():
    print "* ",k,"=",v
# Out:
# LAB AND MODEL SETTINGS:
# ------------------------
# *  listof_home_vars = ./input_labs/cerfacs/home_vars/listof_primavera_extra_vars.txt
# *  tierMax = 3
# *  grids = {'HR': {'nemo': ['gn', '', '25 km', 'native ocean tri-polar grid ORCA025 with 1.47 M ocean cells'], 'arpsfx': ['gn', 'gaussian-reduced_HR', '50 km', 'native atmosphere T359l reduced gaussian grid']}, 'LR': {'nemo': ['gn', '', '100 km', 'native ocean tri-polar grid ORCA1 with 105 k ocean cells'], 'arpsfx': ['gn', 'gaussian-reduced_LR', '250 km', 'native atmosphere T127l reduced gaussian grid']}}
# *  path_to_parse = ./input_labs/cerfacs/to_parse/for_toy_grid_LR
# *  excluded_vars = ['clcalipso', 'clcalipso2', 'clhcalipso', 'clcalipsoice', 'clcalipsoliq', 'cllcalipso', 'clmcalipso', 'cltcalipso', 'cfadLidarsr532', 'cfadDbze94', 'cfadLidarsr532', 'clisccp', 'cltisccp', 'climodis', 'clwmodis', 'jpdftaureicemodis', 'cltmodis', 'clmisr', 'parasolRefl']
# *  model_timestep = {'nemo': 900.0, 'arpsfx': 900.0}
# *  realms_per_context = {'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'], 'arpsfx': ['atmos', 'atmos atmosChem', 'aerosol', 'atmos land', 'land', 'landIce land', 'aerosol land', 'land landIce', 'landIce']}
# *  max_file_size_in_floats = 500000000.0
# *  path_extra_tables = ./input_labs/cerfacs/extra_Tables
# *  ping_variables_prefix = CMIP6_
# *  comments = {}
# *  grid_choice = {'CNRM-ESM2-1': 'LR', 'CNRM-ESM2-1-HR': 'HR', 'CNRM-CM6-1': 'LR', 'CNRM-CM6-1-HR': 'HR'}
# *  orphan_variables = {'nemo': ['dummy_variable_for_illustration_purpose'], 'arpsfx': []}
# *  vars_OK = {}
# *  max_priority = 2
# *  info_url = http://www.umr-cnrm.fr/cmip6/
# *  institution_id = CNRM-CERFACS
# *  excluded_spshapes = ['XYA-na', 'XYG-na', 'S-na', 'S-AH', 'S-A', 'na-A']
# *  mips = HighResMIP
# *  use_union_zoom = False
# *  source_types = {'CNRM-ESM2-1': 'ESM', 'CNRM-ESM2-1-HR': 'ESM', 'CNRM-CM6-1': 'AOGCM', 'CNRM-CM6-1-HR': 'AOGCM'}
# *  sizes = [105704, 75, 32768, 91, 30, 14, 128]
# *  mips_all = set(['C4MIP', 'CORDEX', 'ISMIP6', 'GMMIP', 'LUMIP', 'PMIP', 'RFMIP', 'DAMIP', 'AerChemMIP', 'SIMIP', 'FAFMIP', 'CFMIP', 'ScenarioMIP', 'LS3MIP', 'OMIP', 'GeoMIP'])
# *  contact = contact.cmip6@cerfacs.fr
# *  output_path = @IOXDIR@/
# *  grid_policy = adhoc
# *  source_id = CNRM-CM6-1
#
# SIMULATION SETTINGS:
# ---------------------
# *  activity_id = HighResMIP
# *  parent_source_id = CNRM-CM5.1
# *  variant_info = none
# *  parent_experiment_id = no parent
# *  parent_activity_id = CMIP
# *  source_type = AGCM
# *  physics_index = 1
# *  sub_experiment_id = none
# *  branch_time_in_parent = 365.0D0
# *  project = CMIP6
# *  sub_experiment = none
# *  branch_method = standard
# *  initialization_index = 1
# *  realization_index = 1
# *  comments = {}
# *  forcing_index = 1
# *  branch_time_in_child = 0.0D0
# *  parent_mip_era = CMIP5
# *  experiment_id = Forced-Atmos-Land
# *  history = none

# %%
# In/Out directory
my_dir="output_labs/"+lab+"/"

# %%
#help(generate_file_defs)

# %%
if False : 
    #for my_context in lab_and_model_settings["realms_per_context"].keys():
    for my_context in ["arpsfx"]:
        generate_file_defs(lab_and_model_settings, simulation_settings,year=2000,context=my_context,
                    pingfile=my_dir+"ping_"+my_context+".xml", printout=True, 
                    cvs_path=my_cvspath,dummies='include', dirname=my_dir)

# %% [markdown]
# ## 4. After some edit in ping files, which does not discard every 'dummy' entries

# %%
note="VERSIONS:"
print note
print "-"*len(note)

from dr2xml import generate_file_defs
# Out:
# VERSIONS:
# ---------

# %%
note="\nLAB AND MODEL SETTINGS:"
print note
print "-"*len(note)

for k,v in lab_and_model_settings.items():
    print "* ",k,"=",v
    
note="\nSIMULATION SETTINGS:"
print note
print "-"*len(note)

for k,v in simulation_settings.items():
    print "* ",k,"=",v
# Out:
# LAB AND MODEL SETTINGS:
# ------------------------
# *  listof_home_vars = ./input_labs/cerfacs/home_vars/listof_primavera_extra_vars.txt
# *  tierMax = 3
# *  grids = {'HR': {'nemo': ['gn', '', '25 km', 'native ocean tri-polar grid ORCA025 with 1.47 M ocean cells'], 'arpsfx': ['gn', 'gaussian-reduced_HR', '50 km', 'native atmosphere T359l reduced gaussian grid']}, 'LR': {'nemo': ['gn', '', '100 km', 'native ocean tri-polar grid ORCA1 with 105 k ocean cells'], 'arpsfx': ['gn', 'gaussian-reduced_LR', '250 km', 'native atmosphere T127l reduced gaussian grid']}}
# *  path_to_parse = ./input_labs/cerfacs/to_parse/for_toy_grid_LR
# *  excluded_vars = ['clcalipso', 'clcalipso2', 'clhcalipso', 'clcalipsoice', 'clcalipsoliq', 'cllcalipso', 'clmcalipso', 'cltcalipso', 'cfadLidarsr532', 'cfadDbze94', 'cfadLidarsr532', 'clisccp', 'cltisccp', 'climodis', 'clwmodis', 'jpdftaureicemodis', 'cltmodis', 'clmisr', 'parasolRefl']
# *  model_timestep = {'nemo': 900.0, 'arpsfx': 900.0}
# *  realms_per_context = {'nemo': ['seaIce', 'ocean', 'ocean seaIce', 'ocnBgchem', 'seaIce ocean'], 'arpsfx': ['atmos', 'atmos atmosChem', 'aerosol', 'atmos land', 'land', 'landIce land', 'aerosol land', 'land landIce', 'landIce']}
# *  max_file_size_in_floats = 500000000.0
# *  path_extra_tables = ./input_labs/cerfacs/extra_Tables
# *  ping_variables_prefix = CMIP6_
# *  comments = {}
# *  grid_choice = {'CNRM-ESM2-1': 'LR', 'CNRM-ESM2-1-HR': 'HR', 'CNRM-CM6-1': 'LR', 'CNRM-CM6-1-HR': 'HR'}
# *  orphan_variables = {'nemo': ['dummy_variable_for_illustration_purpose'], 'arpsfx': []}
# *  vars_OK = {}
# *  max_priority = 2
# *  info_url = http://www.umr-cnrm.fr/cmip6/
# *  institution_id = CNRM-CERFACS
# *  excluded_spshapes = ['XYA-na', 'XYG-na', 'S-na', 'S-AH', 'S-A', 'na-A']
# *  mips = HighResMIP
# *  use_union_zoom = False
# *  source_types = {'CNRM-ESM2-1': 'ESM', 'CNRM-ESM2-1-HR': 'ESM', 'CNRM-CM6-1': 'AOGCM', 'CNRM-CM6-1-HR': 'AOGCM'}
# *  sizes = [105704, 75, 32768, 91, 30, 14, 128]
# *  mips_all = set(['C4MIP', 'CORDEX', 'ISMIP6', 'GMMIP', 'LUMIP', 'PMIP', 'RFMIP', 'DAMIP', 'AerChemMIP', 'SIMIP', 'FAFMIP', 'CFMIP', 'ScenarioMIP', 'LS3MIP', 'OMIP', 'GeoMIP'])
# *  contact = contact.cmip6@cerfacs.fr
# *  output_path = @IOXDIR@/
# *  grid_policy = adhoc
# *  source_id = CNRM-CM6-1
#
# SIMULATION SETTINGS:
# ---------------------
# *  activity_id = HighResMIP
# *  parent_source_id = CNRM-CM5.1
# *  variant_info = none
# *  parent_experiment_id = no parent
# *  parent_activity_id = CMIP
# *  source_type = AGCM
# *  physics_index = 1
# *  sub_experiment_id = none
# *  branch_time_in_parent = 365.0D0
# *  project = CMIP6
# *  sub_experiment = none
# *  branch_method = standard
# *  initialization_index = 1
# *  realization_index = 1
# *  comments = {}
# *  forcing_index = 1
# *  branch_time_in_child = 0.0D0
# *  parent_mip_era = CMIP5
# *  experiment_id = Forced-Atmos-Land
# *  history = none

# %%
# In/Out directory
#my_dir="../pingfiles_edited/"+lab+"/"
#my_dir="../pingfiles_reduced/"+lab+"/"
my_dir=lab_and_model_settings["path_to_parse"]+"/"

# %%
# after some edit in the ping files, which does not discard every 'dummy' entries 
if True :
    #for my_context in lab_and_model_settings["realms_per_context"].keys():  
    for my_context in ["arpsfx"]:       
        generate_file_defs(lab_and_model_settings, simulation_settings,year=2000,context=my_context,
                    pingfile=my_dir+"ping_"+my_context+".xml", printout=True, 
                    cvs_path=my_cvspath,dummies='include', dirname=my_dir)
# Out:
# Error : reference 'CMIP6_pblz' is invalid
# Error : reference 'CMIP6_pblz' is invalid
# Error : reference 'CMIP6_pblz' is invalid
# Error : reference 'CMIP6_pblz' is invalid
# Number of Request Links which apply to MIPS HighResMIP  is:  31
# Number of Request Links which apply to experiment  Forced-Atmos-Land and MIPs HighResMIP  is:  27
# Number of (CMOR variable, grid) pairs for these requestLinks is :480
# Number once filtered by excluded vars is : 464
# Number of distinct CMOR variables (whatever the grid) : 456
# Number of distinct var labels is : 323
# DR Error: issue with stdname for pod0 in AERmon  => take the MIPvar label instead.
# DR Error: issue with stdname for wtem in EmonZ  => take the MIPvar label instead.
# DR Error: issue with stdname for od550so4 in AERmon  => take the MIPvar label instead.
# DR Error: issue with stdname for prcsh in E3hr  => take the MIPvar label instead.
# DR Error: issue with stdname for od550no3 in AERmon  => take the MIPvar label instead.
# DR Error: issue with stdname for vtendnogw in EmonZ  => take the MIPvar label instead.
#
# Number of simplified vars is : 456
# Info: dimid corresponding to  height50m for variable wind50mmin in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable wind50mmax in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable wsgmax50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim1hr  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim3hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable va50m in Table PRIMAVERA_Prim6hrPt  not found in DR => read it in extra coordinates Table:  height
# Info: dimid corresponding to  height50m for variable ua50m in Table PRIMAVERA_Prim6hrPt  not found in DR => read it in extra coordinates Table:  height
# Number of 'cmor' and 'perso' among home variables:  0
# Number of 'extra' among home variables:  173
#
# Realms for these CMORvars : ['seaIce', 'seaIce ocean', 'land', 'atmos atmosChem', 'landIce', 'landIce land', 'land landIce', 'atmos', 'aerosol', 'ocean']
# Warning:  rsds  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  psl  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rsus  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  huss  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  hfls  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  sfcWind  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  prw  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  tauv  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  clt  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  hurs  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  fco2nat  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  tas  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  clwvi  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rtmt  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rlus  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rsdscs  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  ts  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  prsn  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  prc  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rlut  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  clivi  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  ci  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  uas  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rlutcs  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  sci  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rsut  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  vas  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  ccb  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rlds  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  fco2antt  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rsdt  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  ps  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  fco2fos  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  hfss  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rsuscs  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rsutcs  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  evspsbl  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  pr  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  cct  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  tauu  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  rldscs  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
# Warning:  sbl  in table  CFsubhr  has been excluded for one or several of the following reason(s):
#    * has an excluded spatial shape: S-na
#
# file_def written as ./input_labs/cerfacs/to_parse/for_toy_grid_LR/dr2xml_arpsfx.xml
#
# Tables concerned by context arpsfx :  ['E1hr', 'Prim3hrPt', 'Prim3hr', 'Prim6hr', 'CFday', 'LImon', 'Prim6hrPt', '3hr', 'CFmon', 'day', 'Primmon', 'Primday', 'EmonZ', 'PrimdayPt', 'Amon', '6hrPlev', 'AERmon', 'E3hrPt', '6hrPlevPt', 'Eday', 'E3hr', 'Prim1hr', 'PrimmonZ', 'Emon', 'Lmon']
#
# Variables per table :
#            E1hr 02 ----> pr(1) prc(1)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)       Prim3hrPt 13 ----> vortmean(1.0) ua100m(1.0) va100m(1.0) va50m(1.0) ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) ua50m(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)         Prim3hr 03 ----> sfcWindmax(1.0) evspsbl(1.0) sfcWind(1.0)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)         Prim6hr 15 ----> pr(1.0) tntc(1.0) tntscp(1.0) ps(1.0) sfcWindmax(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)           CFday 29 ----> phalf(1) albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)           LImon 10 ----> snc(1) snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)       Prim6hrPt 08 ----> ua100m(1.0) va100m(1.0) va50m(1.0) hus1000(1.0) thetapv2(1.0) ua50m(1.0) va1000(1.0) ua1000(1.0)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
# ...
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)            Emon 37 ----> ta27(2) rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)            Lmon 54 ----> pastureFrac(1) rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
# Skipped variables (i.e. whose alias is not present in the pingfile):
#
#            E1hr 02/02 ----> pr prc(1)
#           EmonZ 09/09 ----> epfy utendepfd(2) ygwdparam(2) utendnogw(2) wtem(2) vtem(2) epfz(1) xgwdparam(2) vtendnogw(2)
#       PrimdayPt 02/02 ----> va ua(1.0)
#       Prim3hrPt 09/13 ----> vortmean ua100(1.0) zg7h(1.0) hus1000(1.0) hus100(1.0) ta100(1.0) va100(1.0) va1000(1.0) ua1000(1.0)
#            Amon 41/43 ----> clw co2massClim(1) hus(1) co2Clim(1) pfull(1) rsus(1) ps(1) hfss(1) rlutcs(1) rlus(1) cl(1) mc(1) clt(1) rsut(1) wap(1) ua(1) pr(1) co2mass(1) zg(1) rsds(1) rlds(1) hfls(1) phalf(1) va(1) ta(1) cli(1) hur(1) clivi(1) rsutcs(1) rlut(1) co2(1) ch4(1) n2oglobalClim(1) ch4global(1) n2o(1) o3(1) n2oClim(1) o3Clim(1) ch4globalClim(1) ch4Clim(1) n2oglobal(1)
#         Prim3hr 02/03 ----> evspsbl sfcWind(1.0)
#         Prim6hr 14/15 ----> pr tntc(1.0) tntscp(1.0) ps(1.0) tntpbl(1.0) wsgmax(1.0) hus4(1.0) ua4(1.0) tntrl(1.0) rsds(1.0) clt(1.0) tntrs(1.0) va4(1.0) rsdsdiff(1.0)
#            E3hr 10/10 ----> rlut rsutcs(2) prw(2) clivi(2) clwvi(2) psl(2) rlutcs(2) prcsh(1) rsdt(2) rsut(2)
#         6hrPlev 02/02 ----> hus4 wap4(1)
#          AERmon 73/73 ----> ua drynoy(1) od550ss(1) ztp(1) chepsoa(1) pod0(1) rsutcsaf(1) rsutaf(1) wetso2(1) reffclwtop(1) od550lt1aer(1) tropoz(1) od550aerh2o(1) dryso2(1) od550bc(1) rlutaf(1) wetss(1) emidms(1) od550so4(1) emibvoc(1) emibc(1) eminh3(1) od550soa(1) wetnoy(1) emiso2(1) albs(1) eminox(1) emioa(1) tatp(1) wetbc(1) emico(1) lwp(1) wetnh4(1) emiaco(1) od440aer(1) drynh4(1) od870aer(1) dryss(1) ccn(1) ptp(1) emiso4(1) va(1) dryoa(1) od550aer(1) emiaoa(1) toz(1) albsrfc(1) drydust(1) abs550aer(1) rlutcsaf(1) od550oa(1) wetnh3(1) od550bb(1) emidust(1) emivoc(1) cltc(1) wetoa(1) bldep(1) od550dust(1) emianox(1) od550no3(1) emiss(1) drynh3(1) cod(1) emiisop(1) dryso4(1) chepasoa(1) wetdust(1) drybc(1) dryo3(1) wetso4(1) ttop(1) od550csaer(1)
#           CFday 29/29 ----> phalf albisccp(1) rlutcs(1) wap(1) clw(1) rsut(1) zg(1) pctisccp(1) mc(1) rsdt(1) ta(1) cl(1) cct(1) ps(1) hus(1) rsdscs(1) hur(1) wap500(1) clivi(1) ua(1) va(1) rsuscs(1) rsutcs(1) ta700(1) ccb(1) cli(1) clwvi(1) rldscs(1) pfull(1)
#          E3hrPt 08/08 ----> va7h hus7h(2) ua7h(2) va850(1) ta7h(2) psl(1) wap7h(2) ua850(1)
#           LImon 10/10 ----> snc snd(1) sootsn(2) agesno(1) snw(1) lwsnl(2) tsn(1) hfdsn(1) snm(1) sbl(1)
#       6hrPlevPt 15/15 ----> va wbptemp7h(1) ua7h(1) uas(1) vas(1) ua(1) hus7h(1) vortmean(1) ta7h(1) rv850(1) va7h(1) zg7h(1) ta(1) psl(1) zg500(1)
#            Eday 05/05 ----> ts ua(1) va(1) tauv(1) tauu(1)
#       Prim6hrPt 04/08 ----> hus1000 thetapv2(1.0) va1000(1.0) ua1000(1.0)
#             3hr 22/22 ----> rsdscs tas(1) ps(1) hfls(1) clt(1) rsus(1) rlds(1) uas(1) rsdsdiff(1) huss(1) prc(1) rsds(1) pr(1) rsuscs(1) prsn(1) hfss(1) rlus(1) rldscs(1) vas(1) mrro(1) mrsos(1) tslsi(1)
#         Prim1hr 19/24 ----> rsdsmin rsdsdiffmin(2.0) wind100mmin(2.0) wind100mmax(2.0) uas(1.0) wsgmax(2.0) wind50mmin(2.0) wsgmax100m(2.0) rsdsdiff(1.0) ps(2.0) tas(2.0) wind50mmax(2.0) rsdsmax(2.0) wsgmax50m(2.0) clt(2.0) vas(1.0) rsdsdiffmax(2.0) rsds(1.0) sfcWindmin(2.0)
#           CFmon 49/49 ----> rsdcs4co2 rlucs(1) clws(2) clc(2) tnhusscpbl(1) albisccp(1) tntscpbl(1) pctisccp(1) tnhusa(1) tntmp(1) tnhusmp(1) smc(2) rsd(1) mcd(2) rlu4co2(1) rldcs(1) ta(1) evu(1) hur(1) rsdcs(1) dmc(2) rsut4co2(1) tnt(1) edt(1) clis(2) clic(2) rsu4co2(1) rsucs4co2(1) rld4co2(1) clwc(2) rldcs4co2(1) cls(2) tnhusc(1) rlu(1) rsucs(1) rsu(1) tnta(1) hus(1) rlutcs4co2(1) rlut4co2(1) rlucs4co2(1) rsutcs4co2(1) mcu(2) tnhus(1) rsd4co2(1) tntr(1) tnhusd(1) tntc(1) rld(1)
#            Emon 37/37 ----> ta27 rainmxrat27(2) vt(2) snowmxrat27(2) wap(2) vwap(2) grplmxrat27(2) vqint(1) cldicemxrat27(2) twap(2) t2(2) ut(2) hus27(2) wap2(2) columnmassflux(2) clwvic(1) v2(2) uqint(1) ygwdparam(2) va27(2) cldwatmxrat27(2) uwap(2) hus(1) u2(2) uv(2) ua27(2) tntmp27(2) xgwdparam(2) zg27(2) tntrs27(2) tntrl27(2) vegHeight(2) fLuc(1) nep(1) cWood(2) cSoil(1) cMisc(2)
#             day 32/36 ----> uas tas(1) ua(1) clt(1) prsn(1) hfss(1) rlus(1) rlut(1) psl(1) prc(1) sfcWind(1) hus(1) huss(1) zg(2) ta(1) vas(1) hursmin(1) rsds(1) hfls(1) rlds(1) hur(1) pr(1) hurs(1) wap(1) va(1) rsus(1) mrsos(1) tslsi(1) mrro(1) mrso(1) snw(1) snc(1)
#        PrimmonZ 08/08 ----> epfluxdiv vstarbar(2.0) wstarbar(2.0) xnonoroggwdparam(2.0) ua(2.0) ynonoroggwdparam(2.0) va(1.0) zg(1.0)
#         Primmon 46/46 ----> tnsclwmi tnsclihenv(2.0) tnsclibfpcl(2.0) tnscliricl(2.0) tnsclihencl(2.0) tnsccwacr(2.0) tnsclwcm(2.0) tnsclwri(2.0) tnsclids(2.0) reffclwc(1.0) tnsclirir(2.0) tnsclwhon(2.0) tnsccwbl(2.0) tnsclw(2.0) lwp(1.0) tnsclwa(2.0) tnsclimcl(2.0) reffclws(1.0) tnsclia(2.0) tnscli(2.0) tnsclwhen(2.0) cdnc(1.0) tnsclihon(2.0) tnscliif(2.0) tnsclicm(2.0) tnsccwa(2.0) tnsccwif(2.0) tnsclibl(2.0) tnscliemi(2.0) tnsccwce(2.0) tnsccw(2.0) tnsclwcd(2.0) tnsclwbfpcli(2.0) clwvic(1.0) tnsccwcm(2.0) tnsclwce(2.0) tnsclias(2.0) tnsccwacs(2.0) tnsclwac(2.0) cod(1.0) tnsclwbl(2.0) tnsclimr(2.0) tnscliag(2.0) tnsclicd(2.0) tnsclwar(2.0) tnsclwas(2.0)
#            Lmon 54/54 ----> pastureFrac rGrowth(2) mrlsl(1) burntArea(1) rh(1) mrsos(1) cLitter(1) mrros(1) fVegSoil(1) npp(1) cropFrac(1) cProduct(1) cLeaf(2) lai(1) treeFracPrimDec(2) nbp(1) gpp(1) nppRoot(2) fGrazing(1) residualFrac(1) cSoilFast(2) cVeg(1) fHarvest(1) mrro(1) landCoverFrac(2) fLitterSoil(1) mrso(1) fFire(1) c3PftFrac(2) evspsblveg(1) evspsblsoi(1) prveg(2) tran(1) treeFrac(1) cCwd(2) cSoilSlow(2) cLitterAbove(2) c4PftFrac(2) baresoilFrac(1) cLitterBelow(2) cRoot(2) treeFracSecEver(2) rMaint(2) nppLeaf(2) grassFrac(1) treeFracPrimEver(2) cSoilMedium(2) fVegLitter(1) nppWood(2) tsl(2) shrubFrac(1) ra(1) treeFracSecDec(2) mrfso(1)
#         Primday 18/18 ----> evspsbl ua10(1.0) ta19(2.0) ua19(2.0) hus19(2.0) va10(1.0) ts(1.0) wap19(2.0) uneutrals(1.0) vneutrals(1.0) va19(2.0) ta10(1.0) hus10(1.0) prmin(1.0) wap10(1.0) prmax(1.0) mrso(1.0) mrlsl(1.0)
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-16-757bdff0ff93> in <module>()
#       5         generate_file_defs(lab_and_model_settings, simulation_settings,year=2000,context=my_context,
#       6                     pingfile=my_dir+"ping_"+my_context+".xml", printout=True,
# ----> 7                     cvs_path=my_cvspath,dummies='skip', dirname=my_dir)
#
# /Users/moine/Codes/MyDevel_Codes/CMIP6_DATA_SUITE/DR2XML/dr2pub_mpmoine/dr2xml.py in generate_file_defs(lset, sset, year, context, cvs_path, pingfile, dummies, printout, dirname, prefix)
#    1189
#    1190     # mpmoine_petitplus:generate_file_defs: pour sortir des stats sur ce que l'on sort reelement
# -> 1191     if printout: print_SomeStats(context,svars_per_table,skipped_vars_per_table)
#    1192
#    1193  # mpmoine_petitplus: nouvelle fonction print_SomeStats (plus d'info sur les skipped_vars, nbre de vars / (shape,freq) )
#
# /Users/moine/Codes/MyDevel_Codes/CMIP6_DATA_SUITE/DR2XML/dr2pub_mpmoine/dr2xml.py in print_SomeStats(context, svars_per_table, skipped_vars_per_table)
#    1224         stats_out={}
#    1225     for table in svars_per_table.keys():
# -> 1226         for sv in svars_per_table[tbl]:
#    1227                 dic_freq={}
#    1228                 dic_shp={}
#
# NameError: global name 'tbl' is not defined
